# %%
import os
import shutil

# %%
COPY_FROM_PATH = "I:/Qark_R7/R7_S2"
COPY_TO_PATH = "I:/PhD/Model_Building/APKs_and_GitRepos/7_Round"

no_analysis =[]

files = os.listdir(COPY_FROM_PATH)
count =1
for file in files:
    try:
        print (str(count)+": Copying file :" + file)
        src_path = COPY_FROM_PATH+"/"+file+"/Qark_Reversed"
        print("src_path: ", src_path)
        os.chdir(COPY_TO_PATH+"/"+file)
        
        if os.path.exists('Qark_Reversed'):
            shutil.rmtree("Qark_Reversed")            
        
        dst_path=COPY_TO_PATH+"/"+file
        #shutil.copy(src_path, dst_path)
        shutil.move(src_path, dst_path)
        print("dst_path: ", dst_path)       
        
        count = count+1
        
    except Exception as e:
        print(e)
        no_analysis.append(file)
        continue
print (no_analysis)
# Out:
# 1: Copying file :web-opac
# src_path:  I:/Qark_R7/R7_S2/web-opac/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/web-opac
# 2: Copying file :webmon
# src_path:  I:/Qark_R7/R7_S2/webmon/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/webmon
# 3: Copying file :websearch
# src_path:  I:/Qark_R7/R7_S2/websearch/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/websearch
# 4: Copying file :website-monitor
# src_path:  I:/Qark_R7/R7_S2/website-monitor/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/website-monitor
# 5: Copying file :webthingify
# src_path:  I:/Qark_R7/R7_S2/webthingify/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/webthingify
# 6: Copying file :webtube
# src_path:  I:/Qark_R7/R7_S2/webtube/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/webtube
# 7: Copying file :weechat
# src_path:  I:/Qark_R7/R7_S2/weechat/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/weechat
# 8: Copying file :wehe
# src_path:  I:/Qark_R7/R7_S2/wehe/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wehe
# 9: Copying file :werewolf
# src_path:  I:/Qark_R7/R7_S2/werewolf/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/werewolf
# 10: Copying file :wetter
# src_path:  I:/Qark_R7/R7_S2/wetter/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wetter
# 11: Copying file :wger-workout-manager
# src_path:  I:/Qark_R7/R7_S2/wger-workout-manager/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wger-workout-manager
# 12: Copying file :whale-shark-and-sardines
# src_path:  I:/Qark_R7/R7_S2/whale-shark-and-sardines/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/whale-shark-and-sardines
# 13: Copying file :whatsapp-twitch-stickers
# src_path:  I:/Qark_R7/R7_S2/whatsapp-twitch-stickers/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/whatsapp-twitch-stickers
# 14: Copying file :whatsapp-web-to-go
# src_path:  I:/Qark_R7/R7_S2/whatsapp-web-to-go/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/whatsapp-web-to-go
# 15: Copying file :whatsdeleted
# src_path:  I:/Qark_R7/R7_S2/whatsdeleted/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/whatsdeleted
# 16: Copying file :when-ze-bus
# src_path:  I:/Qark_R7/R7_S2/when-ze-bus/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/when-ze-bus
# 17: Copying file :where-am-i
# src_path:  I:/Qark_R7/R7_S2/where-am-i/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/where-am-i
# 18: Copying file :wherearetheeyes
# src_path:  I:/Qark_R7/R7_S2/wherearetheeyes/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wherearetheeyes
# 19: Copying file :whereyougo
# src_path:  I:/Qark_R7/R7_S2/whereyougo/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/whereyougo
# 20: Copying file :who-has-my-stuff
# src_path:  I:/Qark_R7/R7_S2/who-has-my-stuff/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/who-has-my-stuff
# 21: Copying file :wifi-ace
# src_path:  I:/Qark_R7/R7_S2/wifi-ace/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wifi-ace
# 22: Copying file :wifi-analyzer
# src_path:  I:/Qark_R7/R7_S2/wifi-analyzer/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wifi-analyzer
# 23: Copying file :wifi-automatic
# src_path:  I:/Qark_R7/R7_S2/wifi-automatic/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wifi-automatic
# 24: Copying file :wifi-camera
# src_path:  I:/Qark_R7/R7_S2/wifi-camera/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wifi-camera
# 25: Copying file :wifi-manager
# src_path:  I:/Qark_R7/R7_S2/wifi-manager/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wifi-manager
# 26: Copying file :wifi-matic
# src_path:  I:/Qark_R7/R7_S2/wifi-matic/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wifi-matic
# 27: Copying file :wifi-privacy-police
# src_path:  I:/Qark_R7/R7_S2/wifi-privacy-police/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wifi-privacy-police
# 28: Copying file :wifi-qr-code-creator
# src_path:  I:/Qark_R7/R7_S2/wifi-qr-code-creator/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wifi-qr-code-creator
# 29: Copying file :wifi-reminders
# src_path:  I:/Qark_R7/R7_S2/wifi-reminders/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wifi-reminders
# 30: Copying file :wifi-warning
# src_path:  I:/Qark_R7/R7_S2/wifi-warning/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wifi-warning
# 31: Copying file :wifi-widget
# src_path:  I:/Qark_R7/R7_S2/wifi-widget/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wifi-widget
# 32: Copying file :wifiautoff
# src_path:  I:/Qark_R7/R7_S2/wifiautoff/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wifiautoff
# 33: Copying file :wifieapsimconf
# src_path:  I:/Qark_R7/R7_S2/wifieapsimconf/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wifieapsimconf
# 34: Copying file :wifikeyboard
# src_path:  I:/Qark_R7/R7_S2/wifikeyboard/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wifikeyboard
# 35: Copying file :wifikeyshare
# src_path:  I:/Qark_R7/R7_S2/wifikeyshare/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wifikeyshare
# 36: Copying file :wigle-wifi-wardriving
# src_path:  I:/Qark_R7/R7_S2/wigle-wifi-wardriving/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wigle-wifi-wardriving
# 37: Copying file :wikimedia-commons-for-muzei-2
# src_path:  I:/Qark_R7/R7_S2/wikimedia-commons-for-muzei-2/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wikimedia-commons-for-muzei-2
# 38: Copying file :wikipedia
# src_path:  I:/Qark_R7/R7_S2/wikipedia/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wikipedia
# 39: Copying file :wikipoff
# src_path:  I:/Qark_R7/R7_S2/wikipoff/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wikipoff
# 40: Copying file :wiktionary
# src_path:  I:/Qark_R7/R7_S2/wiktionary/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wiktionary
# 41: Copying file :wine-cellar
# src_path:  I:/Qark_R7/R7_S2/wine-cellar/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wine-cellar
# 42: Copying file :wire-secure-messenger
# src_path:  I:/Qark_R7/R7_S2/wire-secure-messenger/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wire-secure-messenger
# 43: Copying file :wirebug
# src_path:  I:/Qark_R7/R7_S2/wirebug/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wirebug
# 44: Copying file :wiseradar
# src_path:  I:/Qark_R7/R7_S2/wiseradar/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wiseradar
# 45: Copying file :wlanscanner
# src_path:  I:/Qark_R7/R7_S2/wlanscanner/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wlanscanner
# 46: Copying file :wonderdroid-x
# src_path:  I:/Qark_R7/R7_S2/wonderdroid-x/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wonderdroid-x
# 47: Copying file :word-of-the-day-learn-a-new-word-every-day
# src_path:  I:/Qark_R7/R7_S2/word-of-the-day-learn-a-new-word-every-day/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/word-of-the-day-learn-a-new-word-every-day
# 48: Copying file :word-power-made-easy-2
# src_path:  I:/Qark_R7/R7_S2/word-power-made-easy-2/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/word-power-made-easy-2
# 49: Copying file :word-value
# src_path:  I:/Qark_R7/R7_S2/word-value/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/word-value
# 50: Copying file :wordbook-your-personal-dictionary
# src_path:  I:/Qark_R7/R7_S2/wordbook-your-personal-dictionary/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wordbook-your-personal-dictionary
# 51: Copying file :wordlesolver
# src_path:  I:/Qark_R7/R7_S2/wordlesolver/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wordlesolver
# 52: Copying file :working-time-alert
# src_path:  I:/Qark_R7/R7_S2/working-time-alert/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/working-time-alert
# 53: Copying file :workout-time
# src_path:  I:/Qark_R7/R7_S2/workout-time/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/workout-time
# 54: Copying file :workoutlog
# src_path:  I:/Qark_R7/R7_S2/workoutlog/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/workoutlog
# 55: Copying file :worktimer
# src_path:  I:/Qark_R7/R7_S2/worktimer/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/worktimer
# 56: Copying file :world-clock
# src_path:  I:/Qark_R7/R7_S2/world-clock/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/world-clock
# 57: Copying file :world-clock-weather
# src_path:  I:/Qark_R7/R7_S2/world-clock-weather/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/world-clock-weather
# 58: Copying file :world-scribe
# src_path:  I:/Qark_R7/R7_S2/world-scribe/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/world-scribe
# 59: Copying file :world-weather
# src_path:  I:/Qark_R7/R7_S2/world-weather/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/world-weather
# 60: Copying file :worldmap
# src_path:  I:/Qark_R7/R7_S2/worldmap/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/worldmap
# 61: Copying file :worldscope
# src_path:  I:/Qark_R7/R7_S2/worldscope/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/worldscope
# 62: Copying file :wormhole
# src_path:  I:/Qark_R7/R7_S2/wormhole/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wormhole
# 63: Copying file :wot-tank-quiz
# src_path:  I:/Qark_R7/R7_S2/wot-tank-quiz/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wot-tank-quiz
# 64: Copying file :wpgen
# src_path:  I:/Qark_R7/R7_S2/wpgen/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wpgen
# 65: Copying file :wrek-online
# src_path:  I:/Qark_R7/R7_S2/wrek-online/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wrek-online
# 66: Copying file :writeily-pro-2
# src_path:  I:/Qark_R7/R7_S2/writeily-pro-2/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/writeily-pro-2
# 67: Copying file :wrong-pin-shutdown-2
# src_path:  I:/Qark_R7/R7_S2/wrong-pin-shutdown-2/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wrong-pin-shutdown-2
# 68: Copying file :wrotto
# src_path:  I:/Qark_R7/R7_S2/wrotto/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wrotto
# 69: Copying file :wulkanowy
# src_path:  I:/Qark_R7/R7_S2/wulkanowy/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wulkanowy
# 70: Copying file :wx
# src_path:  I:/Qark_R7/R7_S2/wx/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wx
# 71: Copying file :wyfy
# src_path:  I:/Qark_R7/R7_S2/wyfy/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/wyfy
# 72: Copying file :x-server-2
# src_path:  I:/Qark_R7/R7_S2/x-server-2/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/x-server-2
# 73: Copying file :x11basic
# src_path:  I:/Qark_R7/R7_S2/x11basic/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/x11basic
# 74: Copying file :xabber-2
# src_path:  I:/Qark_R7/R7_S2/xabber-2/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/xabber-2
# 75: Copying file :xabber-classic
# src_path:  I:/Qark_R7/R7_S2/xabber-classic/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/xabber-classic
# 76: Copying file :xbmc-remote
# src_path:  I:/Qark_R7/R7_S2/xbmc-remote/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/xbmc-remote
# 77: Copying file :xbrowsersync
# src_path:  I:/Qark_R7/R7_S2/xbrowsersync/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/xbrowsersync
# 78: Copying file :xclipper-smart-clipboard-manager-for-android
# src_path:  I:/Qark_R7/R7_S2/xclipper-smart-clipboard-manager-for-android/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/xclipper-smart-clipboard-manager-for-android
# 79: Copying file :xcsoar
# src_path:  I:/Qark_R7/R7_S2/xcsoar/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/xcsoar
# 80: Copying file :xearth
# src_path:  I:/Qark_R7/R7_S2/xearth/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/xearth
# 81: Copying file :xenia
# src_path:  I:/Qark_R7/R7_S2/xenia/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/xenia
# 82: Copying file :xia-express
# src_path:  I:/Qark_R7/R7_S2/xia-express/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/xia-express
# 83: Copying file :xmouse
# src_path:  I:/Qark_R7/R7_S2/xmouse/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/xmouse
# 84: Copying file :xournal++
# src_path:  I:/Qark_R7/R7_S2/xournal++/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/xournal++
# 85: Copying file :xoverrideheadphonejackdetection
# src_path:  I:/Qark_R7/R7_S2/xoverrideheadphonejackdetection/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/xoverrideheadphonejackdetection
# 86: Copying file :xposed-downloader
# src_path:  I:/Qark_R7/R7_S2/xposed-downloader/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/xposed-downloader
# 87: Copying file :xposed-installer
# src_path:  I:/Qark_R7/R7_S2/xposed-installer/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/xposed-installer
# 88: Copying file :xprivacylua
# src_path:  I:/Qark_R7/R7_S2/xprivacylua/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/xprivacylua
# 89: Copying file :xscreensaver
# src_path:  I:/Qark_R7/R7_S2/xscreensaver/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/xscreensaver
# 90: Copying file :xskat
# src_path:  I:/Qark_R7/R7_S2/xskat/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/xskat
# 91: Copying file :xtheremotx
# src_path:  I:/Qark_R7/R7_S2/xtheremotx/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/xtheremotx
# 92: Copying file :xvii-messenger-for-vk
# src_path:  I:/Qark_R7/R7_S2/xvii-messenger-for-vk/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/xvii-messenger-for-vk
# 93: Copying file :yaacc
# src_path:  I:/Qark_R7/R7_S2/yaacc/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/yaacc
# 94: Copying file :yaaic
# src_path:  I:/Qark_R7/R7_S2/yaaic/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/yaaic
# 95: Copying file :yacguide
# src_path:  I:/Qark_R7/R7_S2/yacguide/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/yacguide
# 96: Copying file :yacguide-dev
# src_path:  I:/Qark_R7/R7_S2/yacguide-dev/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/yacguide-dev
# 97: Copying file :yaft
# src_path:  I:/Qark_R7/R7_S2/yaft/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/yaft
# 98: Copying file :yaga
# src_path:  I:/Qark_R7/R7_S2/yaga/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/yaga
# 99: Copying file :yahtzee-dicer
# src_path:  I:/Qark_R7/R7_S2/yahtzee-dicer/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/yahtzee-dicer
# 100: Copying file :yalp-store
# src_path:  I:/Qark_R7/R7_S2/yalp-store/Qark_Reversed
# dst_path:  I:/PhD/Model_Building/APKs_and_GitRepos/7_Round/yalp-store
# []
