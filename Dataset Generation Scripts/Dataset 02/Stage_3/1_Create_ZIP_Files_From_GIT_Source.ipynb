# %%
import shutil
import os
import zipfile

# %%
DOWNLOAD_BASE_PATH = "I:/PhD/Model_Building/APKs_and_GitRepos/7_Round"

# %%
def create_zip_file(path, file_name):
    print("Creating zip file from original source code")
    path = path+"/"+file_name+"/app"    
    zipfile_handler = zipfile.ZipFile(file_name+'.zip', 'w', zipfile.ZIP_DEFLATED)        
    
    for root, dirs, files in os.walk(path):
        for file in files:
            zipfile_handler.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), os.path.join(path, '..')))
            
    zipfile_handler.close()

# %%
def rename_git_repo_folder(path, current_name, new_name):
    print ("Renaming current GIT repo folder name : "+current_name+" to :"+new_name)
    os.chdir(path)    
    os.rename(current_name, new_name)

# %%
def execute_process():
    print("***************Process started***************")
    files = os.listdir(DOWNLOAD_BASE_PATH)
    
    for file in files:
        print("***************App Name : "+file+"***************")
        sub_files = os.listdir(DOWNLOAD_BASE_PATH+"/"+file)        
        for sub_file in sub_files:      
            
            try:
                if(str(sub_file) not in [file+".apk", "MobSF_Reversed", "Qark_Reversed", file+".zip"]):
                    path = DOWNLOAD_BASE_PATH+"/"+file
                    rename_git_repo_folder(path ,sub_file, file)
                    create_zip_file(path, file)
            except Exception as e:
                print(e)
    print("***************Process completed***************")

# %%
execute_process()
# Out:
# ***************Process started***************
# ***************App Name : us-travel-converter***************
# Renaming current GIT repo folder name : USTravelConverter to :us-travel-converter
# Creating zip file from original source code
# ***************App Name : usb-hid-terminal***************
# Renaming current GIT repo folder name : USBHIDTerminal to :usb-hid-terminal
# Creating zip file from original source code
# ***************App Name : usercontrolled-decryption-operations***************
# Renaming current GIT repo folder name : user-controlled-decryption-operations to :usercontrolled-decryption-operations
# Creating zip file from original source code
# ***************App Name : userhash***************
# Renaming current GIT repo folder name : UhLocationReportingService to :userhash
# Creating zip file from original source code
# ***************App Name : userland***************
# Renaming current GIT repo folder name : UserLAnd to :userland
# Creating zip file from original source code
# ***************App Name : uuid-0xfd6f-scanner***************
# Renaming current GIT repo folder name : UUID0xFD6FTracer to :uuid-0xfd6f-scanner
# Creating zip file from original source code
# ***************App Name : v2ex***************
# Renaming current GIT repo folder name : v2ex-simple to :v2ex
# Creating zip file from original source code
# ***************App Name : v2ray***************
# Renaming current GIT repo folder name : v2ray-plugin-android to :v2ray
# Creating zip file from original source code
# ***************App Name : vadret***************
# Renaming current GIT repo folder name : android to :vadret
# Creating zip file from original source code
# ***************App Name : valetudo-companion***************
# Renaming current GIT repo folder name : valetudo-companion to :valetudo-companion
# Creating zip file from original source code
# ***************App Name : vanilla-cover-fetcher***************
# Renaming current GIT repo folder name : vanilla-music-cover-fetch to :vanilla-cover-fetcher
# Creating zip file from original source code
# ***************App Name : vanilla-lyrics-search***************
# Renaming current GIT repo folder name : vanilla-music-lyrics-search to :vanilla-lyrics-search
# Creating zip file from original source code
# ***************App Name : vanilla-metadata-fetch***************
# Renaming current GIT repo folder name : vanilla-music-metadata-fetch to :vanilla-metadata-fetch
# Creating zip file from original source code
# ***************App Name : vanilla-music***************
# Renaming current GIT repo folder name : vanilla to :vanilla-music
# Creating zip file from original source code
# ***************App Name : vanilla-tag-editor***************
# Renaming current GIT repo folder name : vanilla-music-tag-editor to :vanilla-tag-editor
# Creating zip file from original source code
# ***************App Name : vaporizer-control-crafty***************
# Renaming current GIT repo folder name : VaporizerControl to :vaporizer-control-crafty
# Creating zip file from original source code
# ***************App Name : varengold-activetan***************
# Renaming current GIT repo folder name : activeTAN-Android to :varengold-activetan
# Creating zip file from original source code
# ***************App Name : vcmi***************
# Renaming current GIT repo folder name : vcmi-android to :vcmi
# Creating zip file from original source code
# ***************App Name : vector-camera***************
# Renaming current GIT repo folder name : VectorCamera to :vector-camera
# Creating zip file from original source code
# ***************App Name : vector-pinball***************
# Renaming current GIT repo folder name : Vector-Pinball to :vector-pinball
# Creating zip file from original source code
# ***************App Name : vectorify-da-home***************
# Renaming current GIT repo folder name : VectorifyDaHome to :vectorify-da-home
# Creating zip file from original source code
# ***************App Name : vedroid-events***************
# Renaming current GIT repo folder name : vedroid-events to :vedroid-events
# Creating zip file from original source code
# ***************App Name : velocity-calculator***************
# Renaming current GIT repo folder name : velocitycalculator to :velocity-calculator
# Creating zip file from original source code
# ***************App Name : verbiste-android***************
# Renaming current GIT repo folder name : verbiste-android to :verbiste-android
# Creating zip file from original source code
# ***************App Name : vernet***************
# Renaming current GIT repo folder name : vernet to :vernet
# Creating zip file from original source code
# ***************App Name : vespucci***************
# Renaming current GIT repo folder name : osmeditor4android to :vespucci
# Creating zip file from original source code
# ***************App Name : veterondo***************
# Renaming current GIT repo folder name : veterondo to :veterondo
# Creating zip file from original source code
# ***************App Name : vi-improved-touch***************
# Renaming current GIT repo folder name : vimtouch to :vi-improved-touch
# Creating zip file from original source code
# ***************App Name : vibe***************
# Renaming current GIT repo folder name : Vibe to :vibe
# Creating zip file from original source code
# ***************App Name : viborafeed***************
# Renaming current GIT repo folder name : ViboraFeed to :viborafeed
# Creating zip file from original source code
# ***************App Name : vibrato***************
# Renaming current GIT repo folder name : vibrato to :vibrato
# Creating zip file from original source code
# ***************App Name : video-transcoder***************
# Renaming current GIT repo folder name : video-transcoder to :video-transcoder
# Creating zip file from original source code
# ***************App Name : vigilante***************
# Renaming current GIT repo folder name : Vigilante to :vigilante
# Creating zip file from original source code
# ***************App Name : vinyl-music-player***************
# Renaming current GIT repo folder name : VinylMusicPlayer to :vinyl-music-player
# Creating zip file from original source code
# ***************App Name : virtualsoftkeys***************
# Renaming current GIT repo folder name : VirtualSoftKeys to :virtualsoftkeys
# Creating zip file from original source code
# ***************App Name : virtualxposed***************
# Renaming current GIT repo folder name : VirtualXposed to :virtualxposed
# Creating zip file from original source code
# ***************App Name : virtuosity***************
# Renaming current GIT repo folder name : virtuosity to :virtuosity
# Creating zip file from original source code
# ***************App Name : virus-attack***************
# Renaming current GIT repo folder name : virus-attack to :virus-attack
# Creating zip file from original source code
# ***************App Name : visualizer***************
# Renaming current GIT repo folder name : android-visualizer to :visualizer
# Creating zip file from original source code
# ***************App Name : vitosha-blackjack***************
# Renaming current GIT repo folder name : vitosha-blackjack to :vitosha-blackjack
# Creating zip file from original source code
# ***************App Name : vitoshadm***************
# Renaming current GIT repo folder name : VitoshaDM to :vitoshadm
# Creating zip file from original source code
# ***************App Name : vitoshapokerodds***************
# Renaming current GIT repo folder name : android-vitosha-poker-odds to :vitoshapokerodds
# Creating zip file from original source code
# ***************App Name : vlc***************
# Renaming current GIT repo folder name : vlc-android to :vlc
# Creating zip file from original source code
# ***************App Name : vlcfreemote***************
# Renaming current GIT repo folder name : VlcFreemote to :vlcfreemote
# Creating zip file from original source code
# ***************App Name : vlille-checker***************
# Renaming current GIT repo folder name : vlilleChecker to :vlille-checker
# Creating zip file from original source code
# ***************App Name : vocabletrainer***************
# Renaming current GIT repo folder name : VocableTrainer-Android to :vocabletrainer
# Creating zip file from original source code
# ***************App Name : voice-notify***************
# Renaming current GIT repo folder name : voicenotify to :voice-notify
# Creating zip file from original source code
# ***************App Name : voice-recorder***************
# Renaming current GIT repo folder name : Simple-Voice-Recorder to :voice-recorder
# Creating zip file from original source code
# ***************App Name : voicesmith***************
# Renaming current GIT repo folder name : voicesmith to :voicesmith
# Creating zip file from original source code
# ***************App Name : voipms-sms***************
# Renaming current GIT repo folder name : voipms-sms-client to :voipms-sms
# Creating zip file from original source code
# ***************App Name : volta***************
# Renaming current GIT repo folder name : Volta to :volta
# Creating zip file from original source code
# ***************App Name : voltage-drop-calculator***************
# Renaming current GIT repo folder name : voltagedrop to :voltage-drop-calculator
# Creating zip file from original source code
# ***************App Name : volume-control***************
# Renaming current GIT repo folder name : Volume-Control to :volume-control
# Creating zip file from original source code
# ***************App Name : volume-control-2***************
# Renaming current GIT repo folder name : volume_control_android to :volume-control-2
# Creating zip file from original source code
# ***************App Name : volumelockr***************
# Renaming current GIT repo folder name : VolumeLockr to :volumelockr
# Creating zip file from original source code
# ***************App Name : voodoo-carrieriq-detector***************
# Renaming current GIT repo folder name : simple_carrieriq_detector_app to :voodoo-carrieriq-detector
# Creating zip file from original source code
# ***************App Name : voodoo-ota-rootkeeper***************
# Renaming current GIT repo folder name : ota-rootkeeper-app to :voodoo-ota-rootkeeper
# Creating zip file from original source code
# ***************App Name : voodoo-screen-test-patterns***************
# Renaming current GIT repo folder name : screen-test-patterns-app to :voodoo-screen-test-patterns
# Creating zip file from original source code
# ***************App Name : votar***************
# Renaming current GIT repo folder name : votar to :votar
# Creating zip file from original source code
# ***************App Name : voucher-calc***************
# Renaming current GIT repo folder name : vouchercalc to :voucher-calc
# Creating zip file from original source code
# ***************App Name : voucher-vault***************
# Renaming current GIT repo folder name : vouchervault to :voucher-vault
# Creating zip file from original source code
# ***************App Name : vpn-hotspot***************
# Renaming current GIT repo folder name : VPNHotspot to :vpn-hotspot
# Creating zip file from original source code
# ***************App Name : vpn-hotspot-2***************
# Renaming current GIT repo folder name : VPNHotspot to :vpn-hotspot-2
# Creating zip file from original source code
# ***************App Name : vtu-cs-lab-manual***************
# Renaming current GIT repo folder name : vtu-cs-lab-manual to :vtu-cs-lab-manual
# Creating zip file from original source code
# ***************App Name : vuze-remote***************
# Renaming current GIT repo folder name : vuze-remote-for-android to :vuze-remote
# Creating zip file from original source code
# ***************App Name : vx-connectbot***************
# Renaming current GIT repo folder name : connectbot to :vx-connectbot
# Creating zip file from original source code
# ***************App Name : wairtonow***************
# Renaming current GIT repo folder name : WairToNow to :wairtonow
# Creating zip file from original source code
# ***************App Name : waistline***************
# Renaming current GIT repo folder name : waistline to :waistline
# Creating zip file from original source code
# ***************App Name : walkie-talkie***************
# Renaming current GIT repo folder name : WalkieTalkie to :walkie-talkie
# Creating zip file from original source code
# ***************App Name : wallabag***************
# Renaming current GIT repo folder name : android-app to :wallabag
# Creating zip file from original source code
# ***************App Name : walletcount***************
# Renaming current GIT repo folder name : WalletCount to :walletcount
# Creating zip file from original source code
# ***************App Name : wallxth***************
# Renaming current GIT repo folder name : walleth to :wallxth
# Creating zip file from original source code
# ***************App Name : wanidoku***************
# Renaming current GIT repo folder name : wanidoku to :wanidoku
# Creating zip file from original source code
# ***************App Name : warmd-fight-climate-change***************
# Renaming current GIT repo folder name : Warmd to :warmd-fight-climate-change
# Creating zip file from original source code
# ***************App Name : warmshowers***************
# Renaming current GIT repo folder name : wsandroid to :warmshowers
# Creating zip file from original source code
# ***************App Name : warpclock***************
# Renaming current GIT repo folder name : warpclock to :warpclock
# Creating zip file from original source code
# ***************App Name : warpinator-for-android-unofficial***************
# Renaming current GIT repo folder name : warpinator-android to :warpinator-for-android-unofficial
# Creating zip file from original source code
# ***************App Name : was-geht***************
# Renaming current GIT repo folder name : wasgeht-android to :was-geht
# Creating zip file from original source code
# ***************App Name : wassword-wonderful-password-generator***************
# Renaming current GIT repo folder name : wassword-flutter to :wassword-wonderful-password-generator
# Creating zip file from original source code
# ***************App Name : wasted***************
# Renaming current GIT repo folder name : Wasted to :wasted
# Creating zip file from original source code
# ***************App Name : watertracker***************
# Renaming current GIT repo folder name : WaterTracker to :watertracker
# Creating zip file from original source code
# ***************App Name : waterydroid***************
# Renaming current GIT repo folder name : waterydroid to :waterydroid
# Creating zip file from original source code
# ***************App Name : watomatic-auto-reply-for-whatsapp***************
# Renaming current GIT repo folder name : watomatic to :watomatic-auto-reply-for-whatsapp
# Creating zip file from original source code
# ***************App Name : wator***************
# Renaming current GIT repo folder name : Wa-Tor to :wator
# Creating zip file from original source code
# ***************App Name : watransmitter***************
# Renaming current GIT repo folder name : WhatsAppTransmitter to :watransmitter
# Creating zip file from original source code
# ***************App Name : watt***************
# Renaming current GIT repo folder name : Watt to :watt
# Creating zip file from original source code
# ***************App Name : wave-lines***************
# Renaming current GIT repo folder name : WaveLinesWallpaper to :wave-lines
# Creating zip file from original source code
# ***************App Name : waveup-2***************
# Renaming current GIT repo folder name : wave-up-tasker-plugin to :waveup-2
# Creating zip file from original source code
# ***************App Name : wd-notes***************
# Renaming current GIT repo folder name : wdnotes to :wd-notes
# Creating zip file from original source code
# ***************App Name : weather***************
# Renaming current GIT repo folder name : privacy-friendly-weather to :weather
# Creating zip file from original source code
# ***************App Name : weather-2***************
# Renaming current GIT repo folder name : weather to :weather-2
# Creating zip file from original source code
# ***************App Name : weather-forecast***************
# Renaming current GIT repo folder name : weather-forecast to :weather-forecast
# Creating zip file from original source code
# ***************App Name : weather-notification***************
# Renaming current GIT repo folder name : weather-notification to :weather-notification
# Creating zip file from original source code
# ***************App Name : weather-overview***************
# Renaming current GIT repo folder name : weather-overview to :weather-overview
# Creating zip file from original source code
# ***************App Name : weather-radar***************
# Renaming current GIT repo folder name : WeatherRadar to :weather-radar
# Creating zip file from original source code
# ***************App Name : weather-widget***************
# Renaming current GIT repo folder name : WeatherWidget to :weather-widget
# Creating zip file from original source code
# ***************App Name : weatherlog***************
# Renaming current GIT repo folder name : WeatherLogAndroid to :weatherlog
# Creating zip file from original source code
# ***************App Name : web-media-share***************
# Renaming current GIT repo folder name : WebMediaShare to :web-media-share
# Creating zip file from original source code
# ***************App Name : web-opac***************
# Renaming current GIT repo folder name : opacclient to :web-opac
# Creating zip file from original source code
# ***************App Name : web2pdf***************
# Renaming current GIT repo folder name : Web2PDF to :web2pdf
# Creating zip file from original source code
# ***************App Name : webapps***************
# Renaming current GIT repo folder name : webapps to :webapps
# Creating zip file from original source code
# ***************App Name : webmon***************
# Renaming current GIT repo folder name : webmon to :webmon
# Creating zip file from original source code
# ***************App Name : websearch***************
# Renaming current GIT repo folder name : android-WebSearch to :websearch
# Creating zip file from original source code
# ***************App Name : website-monitor***************
# Renaming current GIT repo folder name : website-monitor to :website-monitor
# Creating zip file from original source code
# ***************App Name : webthingify***************
# Renaming current GIT repo folder name : Webthingify to :webthingify
# Creating zip file from original source code
# ***************App Name : webtube***************
# Renaming current GIT repo folder name : webTube to :webtube
# Creating zip file from original source code
# ***************App Name : weechat***************
# Renaming current GIT repo folder name : weechat-android to :weechat
# Creating zip file from original source code
# ***************App Name : wehe***************
# Renaming current GIT repo folder name : wehe-android to :wehe
# Creating zip file from original source code
# ***************App Name : werewolf***************
# Renaming current GIT repo folder name : privacy-friendly-werewolf to :werewolf
# Creating zip file from original source code
# ***************App Name : wetter***************
# Renaming current GIT repo folder name : Weather to :wetter
# Creating zip file from original source code
# ***************App Name : wger-workout-manager***************
# Renaming current GIT repo folder name : flutter to :wger-workout-manager
# Creating zip file from original source code
# ***************App Name : whale-shark-and-sardines***************
# Renaming current GIT repo folder name : jinbei3d to :whale-shark-and-sardines
# Creating zip file from original source code
# ***************App Name : whatsapp-twitch-stickers***************
# Renaming current GIT repo folder name : WhatsApp-Twitch-Stickers to :whatsapp-twitch-stickers
# Creating zip file from original source code
# ***************App Name : whatsapp-web-to-go***************
# Renaming current GIT repo folder name : WhatsappWebToGo to :whatsapp-web-to-go
# Creating zip file from original source code
# ***************App Name : whatsdeleted***************
# Renaming current GIT repo folder name : WhatsDeleted to :whatsdeleted
# Creating zip file from original source code
# ***************App Name : when-ze-bus***************
# Renaming current GIT repo folder name : when-ze-bus to :when-ze-bus
# Creating zip file from original source code
# ***************App Name : where-am-i***************
# Renaming current GIT repo folder name : src to :where-am-i
# Creating zip file from original source code
# ***************App Name : wherearetheeyes***************
# Renaming current GIT repo folder name : WhereAreTheEyes to :wherearetheeyes
# Creating zip file from original source code
# ***************App Name : whereyougo***************
# Renaming current GIT repo folder name : WhereYouGo to :whereyougo
# Creating zip file from original source code
# ***************App Name : who-has-my-stuff***************
# Renaming current GIT repo folder name : whohasmystuff to :who-has-my-stuff
# Creating zip file from original source code
# ***************App Name : wifi-ace***************
# Renaming current GIT repo folder name : android-wifi-ace to :wifi-ace
# Creating zip file from original source code
# ***************App Name : wifi-analyzer***************
# Renaming current GIT repo folder name : WifiAnalyzer to :wifi-analyzer
# Creating zip file from original source code
# ***************App Name : wifi-automatic***************
# Renaming current GIT repo folder name : WiFi-Automatic to :wifi-automatic
# Creating zip file from original source code
# ***************App Name : wifi-camera***************
# Renaming current GIT repo folder name : android-eye to :wifi-camera
# Creating zip file from original source code
# ***************App Name : wifi-manager***************
# Renaming current GIT repo folder name : privacy-friendly-wifi-manager to :wifi-manager
# Creating zip file from original source code
# ***************App Name : wifi-matic***************
# Renaming current GIT repo folder name : wifimatic-android to :wifi-matic
# Creating zip file from original source code
# ***************App Name : wifi-privacy-police***************
# Renaming current GIT repo folder name : privacypolice to :wifi-privacy-police
# Creating zip file from original source code
# ***************App Name : wifi-qr-code-creator***************
# Renaming current GIT repo folder name : android-wifi-qr-code-generator to :wifi-qr-code-creator
# Creating zip file from original source code
# ***************App Name : wifi-reminders***************
# Renaming current GIT repo folder name : wifireminders to :wifi-reminders
# Creating zip file from original source code
# ***************App Name : wifi-warning***************
# Renaming current GIT repo folder name : wifiwarning to :wifi-warning
# Creating zip file from original source code
# ***************App Name : wifi-widget***************
# Renaming current GIT repo folder name : wifiwidget to :wifi-widget
# Creating zip file from original source code
# ***************App Name : wifiautoff***************
# Renaming current GIT repo folder name : wifiAutOff to :wifiautoff
# Creating zip file from original source code
# ***************App Name : wifieapsimconf***************
# Renaming current GIT repo folder name : WIFI_EAP_SIM_Conf to :wifieapsimconf
# Creating zip file from original source code
# ***************App Name : wifikeyboard***************
# Renaming current GIT repo folder name : wifikeyboard to :wifikeyboard
# Creating zip file from original source code
# ***************App Name : wifikeyshare***************
# Renaming current GIT repo folder name : WiFiKeyShare to :wifikeyshare
# Creating zip file from original source code
# ***************App Name : wigle-wifi-wardriving***************
# Renaming current GIT repo folder name : wigle-wifi-wardriving to :wigle-wifi-wardriving
# Creating zip file from original source code
# ***************App Name : wikimedia-commons-for-muzei-2***************
# Renaming current GIT repo folder name : muzei-commons to :wikimedia-commons-for-muzei-2
# Creating zip file from original source code
# ***************App Name : wikipedia***************
# Renaming current GIT repo folder name : apps-android-wikipedia to :wikipedia
# Creating zip file from original source code
# ***************App Name : wikipoff***************
# Renaming current GIT repo folder name : wikipoff to :wikipoff
# Creating zip file from original source code
# ***************App Name : wiktionary***************
# Renaming current GIT repo folder name : WiktionaryMobile to :wiktionary
# Creating zip file from original source code
# ***************App Name : wine-cellar***************
# Renaming current GIT repo folder name : Cavevin to :wine-cellar
# Creating zip file from original source code
# ***************App Name : wire-secure-messenger***************
# Renaming current GIT repo folder name : wire-android to :wire-secure-messenger
# Creating zip file from original source code
# ***************App Name : wirebug***************
# Renaming current GIT repo folder name : wirebug to :wirebug
# Creating zip file from original source code
# ***************App Name : wiseradar***************
# Renaming current GIT repo folder name : WiseRadar to :wiseradar
# Creating zip file from original source code
# ***************App Name : wlanscanner***************
# Renaming current GIT repo folder name : WLANScanner to :wlanscanner
# Creating zip file from original source code
# ***************App Name : wonderdroid-x***************
# Renaming current GIT repo folder name : wonderdroid-x to :wonderdroid-x
# Creating zip file from original source code
# ***************App Name : word-of-the-day-learn-a-new-word-every-day***************
# Renaming current GIT repo folder name : word-of-the-day to :word-of-the-day-learn-a-new-word-every-day
# Creating zip file from original source code
# ***************App Name : word-power-made-easy-2***************
# Renaming current GIT repo folder name : wordpowermadeeasy to :word-power-made-easy-2
# Creating zip file from original source code
# ***************App Name : word-value***************
# Renaming current GIT repo folder name : WordValueCalculator to :word-value
# Creating zip file from original source code
# ***************App Name : wordbook-your-personal-dictionary***************
# Renaming current GIT repo folder name : wordbook-android to :wordbook-your-personal-dictionary
# Creating zip file from original source code
# ***************App Name : wordlesolver***************
# Renaming current GIT repo folder name : wordlesolver to :wordlesolver
# Creating zip file from original source code
# ***************App Name : working-time-alert***************
# Renaming current GIT repo folder name : workingtimealert to :working-time-alert
# Creating zip file from original source code
# ***************App Name : workout-time***************
# Renaming current GIT repo folder name : workouttime to :workout-time
# Creating zip file from original source code
# ***************App Name : workoutlog***************
# Renaming current GIT repo folder name : WorkoutLog to :workoutlog
# Creating zip file from original source code
# ***************App Name : worktimer***************
# Renaming current GIT repo folder name : worktimer to :worktimer
# Creating zip file from original source code
# ***************App Name : world-clock***************
# Renaming current GIT repo folder name : WorldClock to :world-clock
# Creating zip file from original source code
# ***************App Name : world-clock-weather***************
# Renaming current GIT repo folder name : worldclockwidget to :world-clock-weather
# Creating zip file from original source code
# ***************App Name : world-scribe***************
# Renaming current GIT repo folder name : World-Scribe to :world-scribe
# Creating zip file from original source code
# ***************App Name : world-weather***************
# Renaming current GIT repo folder name : World-Weather to :world-weather
# Creating zip file from original source code
# ***************App Name : worldmap***************
# Renaming current GIT repo folder name : WorldMap to :worldmap
# Creating zip file from original source code
# ***************App Name : worldscope***************
# Renaming current GIT repo folder name : worldscope to :worldscope
# Creating zip file from original source code
# ***************App Name : wormhole***************
# Renaming current GIT repo folder name : mobile-wormhole to :wormhole
# Creating zip file from original source code
# ***************App Name : wot-tank-quiz***************
# Renaming current GIT repo folder name : WoT-Tank-Quiz to :wot-tank-quiz
# Creating zip file from original source code
# ***************App Name : wpgen***************
# Renaming current GIT repo folder name : wpgen to :wpgen
# Creating zip file from original source code
# ***************App Name : wrek-online***************
# Renaming current GIT repo folder name : wrekonline to :wrek-online
# Creating zip file from original source code
# ***************App Name : writeily-pro-2***************
# Renaming current GIT repo folder name : writeily-pro to :writeily-pro-2
# Creating zip file from original source code
# ***************App Name : wrong-pin-shutdown-2***************
# Renaming current GIT repo folder name : wps to :wrong-pin-shutdown-2
# Creating zip file from original source code
# ***************App Name : wrotto***************
# Renaming current GIT repo folder name : wrotto-app to :wrotto
# Creating zip file from original source code
# ***************App Name : wulkanowy***************
# Renaming current GIT repo folder name : wulkanowy to :wulkanowy
# Creating zip file from original source code
# ***************App Name : wx***************
# Renaming current GIT repo folder name : wx to :wx
# Creating zip file from original source code
# ***************App Name : wyfy***************
# Renaming current GIT repo folder name : WyFy to :wyfy
# Creating zip file from original source code
# ***************App Name : x-server-2***************
# Renaming current GIT repo folder name : android-xserver to :x-server-2
# Creating zip file from original source code
# ***************App Name : x11basic***************
# Renaming current GIT repo folder name : X11-Basic to :x11basic
# Creating zip file from original source code
# ***************App Name : xabber-2***************
# Renaming current GIT repo folder name : xabber-android to :xabber-2
# Creating zip file from original source code
# ***************App Name : xabber-classic***************
# Renaming current GIT repo folder name : xabber-2.apk to :xabber-classic
# Creating zip file from original source code
# Renaming current GIT repo folder name : xabber-android to :xabber-classic
# [WinError 183] Cannot create a file when that file already exists: 'xabber-android' -> 'xabber-classic'
# ***************App Name : xbmc-remote***************
# Renaming current GIT repo folder name : android-xbmcremote to :xbmc-remote
# Creating zip file from original source code
# ***************App Name : xbrowsersync***************
# Renaming current GIT repo folder name : app to :xbrowsersync
# Creating zip file from original source code
# ***************App Name : xclipper-smart-clipboard-manager-for-android***************
# Renaming current GIT repo folder name : xclipper-fdroid to :xclipper-smart-clipboard-manager-for-android
# Creating zip file from original source code
# ***************App Name : xcsoar***************
# Renaming current GIT repo folder name : XCSoar to :xcsoar
# Creating zip file from original source code
# ***************App Name : xearth***************
# Renaming current GIT repo folder name : xearth to :xearth
# Creating zip file from original source code
# ***************App Name : xenia***************
# Renaming current GIT repo folder name : xenia to :xenia
# Creating zip file from original source code
# ***************App Name : xia-express***************
# Renaming current GIT repo folder name : xiaExpressAndroid to :xia-express
# Creating zip file from original source code
# ***************App Name : xmouse***************
# Renaming current GIT repo folder name : XMouse to :xmouse
# Creating zip file from original source code
# ***************App Name : xournal++***************
# Renaming current GIT repo folder name : xournalpp_mobile to :xournal++
# Creating zip file from original source code
# ***************App Name : xoverrideheadphonejackdetection***************
# Renaming current GIT repo folder name : xoverrideheadphonejackdetection to :xoverrideheadphonejackdetection
# Creating zip file from original source code
# ***************App Name : xposed-downloader***************
# Renaming current GIT repo folder name : xposed_downloader to :xposed-downloader
# Creating zip file from original source code
# ***************App Name : xposed-installer***************
# Renaming current GIT repo folder name : XposedInstaller to :xposed-installer
# Creating zip file from original source code
# ***************App Name : xprivacylua***************
# Renaming current GIT repo folder name : XPrivacyLua to :xprivacylua
# Creating zip file from original source code
# ***************App Name : xscreensaver***************
# Renaming current GIT repo folder name : xscreensaver to :xscreensaver
# Creating zip file from original source code
# ***************App Name : xskat***************
# Renaming current GIT repo folder name : xskat-android to :xskat
# Creating zip file from original source code
# ***************App Name : xtheremotx***************
# Renaming current GIT repo folder name : etheremote to :xtheremotx
# Creating zip file from original source code
# ***************App Name : xvii-messenger-for-vk***************
# Renaming current GIT repo folder name : XVII to :xvii-messenger-for-vk
# Creating zip file from original source code
# ***************App Name : yaacc***************
# Renaming current GIT repo folder name : yaacc-code to :yaacc
# Creating zip file from original source code
# ***************App Name : yaaic***************
# Renaming current GIT repo folder name : Yaaic to :yaaic
# Creating zip file from original source code
# ***************App Name : yacguide***************
# Renaming current GIT repo folder name : yacguide to :yacguide
# Creating zip file from original source code
# ***************App Name : yacguide-dev***************
# Renaming current GIT repo folder name : yacguide to :yacguide-dev
# Creating zip file from original source code
# ***************App Name : yaft***************
# Renaming current GIT repo folder name : yaft-android to :yaft
# Creating zip file from original source code
# ***************App Name : yaga***************
# Renaming current GIT repo folder name : yaga to :yaga
# Creating zip file from original source code
# ***************App Name : yahtzee-dicer***************
# Renaming current GIT repo folder name : privacy-friendly-dice-game to :yahtzee-dicer
# Creating zip file from original source code
# ***************App Name : yalp-store***************
# Renaming current GIT repo folder name : YalpStore to :yalp-store
# Creating zip file from original source code
# ***************App Name : yalp-store-fork***************
# Renaming current GIT repo folder name : YalpStore to :yalp-store-fork
# Creating zip file from original source code
# ***************App Name : yarc***************
# Renaming current GIT repo folder name : yarc to :yarc
# Creating zip file from original source code
# ***************App Name : yarr***************
# Renaming current GIT repo folder name : yarr to :yarr
# Creating zip file from original source code
# ***************App Name : yasfa***************
# Renaming current GIT repo folder name : YASFA1 to :yasfa
# Creating zip file from original source code
# ***************App Name : yashlang***************
# Renaming current GIT repo folder name : yashlang to :yashlang
# Creating zip file from original source code
# ***************App Name : yaxim***************
# Renaming current GIT repo folder name : yaxim to :yaxim
# Creating zip file from original source code
# ***************App Name : yggdrasil***************
# Renaming current GIT repo folder name : crispa-android to :yggdrasil
# Creating zip file from original source code
# ***************App Name : yidkey-kd***************
# Renaming current GIT repo folder name : YiddishKeyboard to :yidkey-kd
# Creating zip file from original source code
# ***************App Name : yin-yang***************
# Renaming current GIT repo folder name : android-yinyang to :yin-yang
# Creating zip file from original source code
# ***************App Name : ykdroid***************
# Renaming current GIT repo folder name : ykDroid to :ykdroid
# Creating zip file from original source code
# ***************App Name : yokatta***************
# Renaming current GIT repo folder name : app-thesis to :yokatta
# Creating zip file from original source code
# ***************App Name : yoke***************
# Renaming current GIT repo folder name : yoke-android to :yoke
# Creating zip file from original source code
# ***************App Name : your-local-weather***************
# Renaming current GIT repo folder name : your-local-weather to :your-local-weather
# Creating zip file from original source code
# ***************App Name : youtube-listing-app***************
# Renaming current GIT repo folder name : YoutubeListingApp to :youtube-listing-app
# Creating zip file from original source code
# ***************App Name : youtube-stream***************
# Renaming current GIT repo folder name : YouTubeStream to :youtube-stream
# Creating zip file from original source code
# ***************App Name : yubiclip***************
# Renaming current GIT repo folder name : yubiclip-android to :yubiclip
# Creating zip file from original source code
# ***************App Name : yubico-authenticator***************
# Renaming current GIT repo folder name : yubioath-android to :yubico-authenticator
# Creating zip file from original source code
# ***************App Name : yubitotp***************
# Renaming current GIT repo folder name : yubitotp-android to :yubitotp
# Creating zip file from original source code
# ***************App Name : yucata-envoy***************
# Renaming current GIT repo folder name : yucata.envoy to :yucata-envoy
# Creating zip file from original source code
# ***************App Name : zanavi***************
# Renaming current GIT repo folder name : zanavi to :zanavi
# Creating zip file from original source code
# ***************App Name : zandy***************
# Renaming current GIT repo folder name : zandy to :zandy
# Creating zip file from original source code
# ***************App Name : zapp***************
# Renaming current GIT repo folder name : zapp to :zapp
# Creating zip file from original source code
# ***************App Name : zbarcamdemo***************
# Renaming current GIT repo folder name : zbarcam to :zbarcamdemo
# Creating zip file from original source code
# ***************App Name : zen***************
# Renaming current GIT repo folder name : Zen to :zen
# Creating zip file from original source code
# ***************App Name : zensuren***************
# Renaming current GIT repo folder name : Zensuren to :zensuren
# Creating zip file from original source code
# ***************App Name : zephyrlogger***************
# Renaming current GIT repo folder name : ZephyrLogger to :zephyrlogger
# Creating zip file from original source code
# ***************App Name : zeus-2***************
# Renaming current GIT repo folder name : zeus to :zeus-2
# Creating zip file from original source code
# ***************App Name : zimlx***************
# Renaming current GIT repo folder name : ZimLX to :zimlx
# Creating zip file from original source code
# ***************App Name : zorin-connect***************
# Renaming current GIT repo folder name : zorin-connect-android to :zorin-connect
# Creating zip file from original source code
# ***************Process completed***************
