# %%
import json
import requests
from requests_toolbelt.multipart.encoder import MultipartEncoder
import subprocess
import os
import json
import requests
import csv
import pandas as pd
import time

# %%
IP_PORT = "127.0.0.1:8000"
SERVER = "http://"+IP_PORT
MOBSF_BASE_PATH = "D:/PhD/Model_Building/Scanners_and_Decompilers/Scanners/MobSF"
APIKEY = "4a9fc3e94941f832d40975a251056079c9be5406891a934ded21a3c0ecdc5119"

# %%
APPLICATION_BASE_PATH = "D:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/7_Round_MobSF"

# %%
#SOURCE_FILE = "Scanned_App_Details.csv"
#OUTPUT_JSON_PATH = APPLICATION_BASE_PATH+"/Scanned_App_JSON_Files"

SOURCE_FILE = "Scanned_Files_Details.csv"
OUTPUT_JSON_PATH = APPLICATION_BASE_PATH+"/Scanned_Files_JSON_Files"

#SOURCE_FILE = "Scanned_No_Source_Details.csv"
#OUTPUT_JSON_PATH = APPLICATION_BASE_PATH+"/Scanned_No_Source_JSON_Files"

# %%
def start_MobSF_server():
    os.chdir(MOBSF_BASE_PATH)
    command = 'start run.bat '+IP_PORT
    subprocess.call(command, shell = True)
    time.sleep(30)

# %%
def get_vulnerability_data_json(app_name,app_hash):    
    print("Generating JSON report for :"+app_name)
    headers = {'Authorization': APIKEY}
    data = {"hash": app_hash}
    response = requests.post(SERVER + '/api/v1/report_json', data=data, headers=headers)
    
    json_file = open(OUTPUT_JSON_PATH+"/"+app_name+ ".json", "a")
    json_file.write(str(response.text))
    json_file.close()

# %%
def execute_process():
    #start_MobSF_server()
    
    scanned_apps = pd.read_csv(APPLICATION_BASE_PATH+'/'+SOURCE_FILE)
    
    for index, row in scanned_apps.iterrows():
        get_vulnerability_data_json(str(row['app_name']),str(row['app_hash']))

# %%
execute_process()
# Out:
# Generating JSON report for :us-travel-converter
# Generating JSON report for :userland
# Generating JSON report for :uuid-0xfd6f-scanner
# Generating JSON report for :v2ex
# Generating JSON report for :v2ray
# Generating JSON report for :vadret
# Generating JSON report for :valetudo-companion
# Generating JSON report for :vanilla-cover-fetcher
# Generating JSON report for :vanilla-lyrics-search
# Generating JSON report for :vanilla-metadata-fetch
# Generating JSON report for :vanilla-music
# Generating JSON report for :vanilla-tag-editor
# Generating JSON report for :varengold-activetan
# Generating JSON report for :vector-camera
# Generating JSON report for :vector-pinball
# Generating JSON report for :vedroid-events
# Generating JSON report for :velocity-calculator
# Generating JSON report for :verbiste-android
# Generating JSON report for :veterondo
# Generating JSON report for :vibe
# Generating JSON report for :viborafeed
# Generating JSON report for :vibrato
# Generating JSON report for :video-transcoder
# Generating JSON report for :vigilante
# Generating JSON report for :vinyl-music-player
# Generating JSON report for :virtualsoftkeys
# Generating JSON report for :virtuosity
# Generating JSON report for :vlcfreemote
# Generating JSON report for :vlille-checker
# Generating JSON report for :vocabletrainer
# Generating JSON report for :voice-notify
# Generating JSON report for :voice-recorder
# Generating JSON report for :volta
# Generating JSON report for :volume-control-2
# Generating JSON report for :volumelockr
# Generating JSON report for :voucher-calc
# Generating JSON report for :vtu-cs-lab-manual
# Generating JSON report for :wairtonow
# Generating JSON report for :wallabag
# Generating JSON report for :walletcount
# Generating JSON report for :wallxth
# Generating JSON report for :wanidoku
# Generating JSON report for :warmshowers
# Generating JSON report for :warpclock
# Generating JSON report for :warpinator-for-android-unofficial
# Generating JSON report for :wasted
# Generating JSON report for :watertracker
# Generating JSON report for :waterydroid
# Generating JSON report for :watomatic-auto-reply-for-whatsapp
# Generating JSON report for :wator
# Generating JSON report for :watransmitter
# Generating JSON report for :watt
# Generating JSON report for :wave-lines
# Generating JSON report for :waveup-2
# Generating JSON report for :weather
# Generating JSON report for :weather-overview
# Generating JSON report for :weather-radar
# Generating JSON report for :weather-widget
# Generating JSON report for :weatherlog
# Generating JSON report for :web-media-share
# Generating JSON report for :webapps
# Generating JSON report for :webmon
# Generating JSON report for :website-monitor
# Generating JSON report for :webthingify
# Generating JSON report for :webtube
# Generating JSON report for :weechat
# Generating JSON report for :werewolf
# Generating JSON report for :wetter
# Generating JSON report for :whatsapp-twitch-stickers
# Generating JSON report for :whatsapp-web-to-go
# Generating JSON report for :whatsdeleted
# Generating JSON report for :who-has-my-stuff
# Generating JSON report for :wifi-analyzer
# Generating JSON report for :wifi-manager
# Generating JSON report for :wifi-matic
# Generating JSON report for :wifi-qr-code-creator
# Generating JSON report for :wifi-reminders
# Generating JSON report for :wifieapsimconf
# Generating JSON report for :wifikeyshare
# Generating JSON report for :wikipedia
# Generating JSON report for :wikipoff
# Generating JSON report for :wine-cellar
# Generating JSON report for :wire-secure-messenger
# Generating JSON report for :wirebug
# Generating JSON report for :wlanscanner
# Generating JSON report for :wonderdroid-x
# Generating JSON report for :word-of-the-day-learn-a-new-word-every-day
# Generating JSON report for :word-power-made-easy-2
# Generating JSON report for :word-value
# Generating JSON report for :wordbook-your-personal-dictionary
# Generating JSON report for :workoutlog
# Generating JSON report for :worktimer
# Generating JSON report for :world-scribe
# Generating JSON report for :wpgen
# Generating JSON report for :wrek-online
# Generating JSON report for :writeily-pro-2
# Generating JSON report for :wrong-pin-shutdown-2
# Generating JSON report for :wulkanowy
# Generating JSON report for :wx
# Generating JSON report for :wyfy
# Generating JSON report for :x11basic
# Generating JSON report for :xclipper-smart-clipboard-manager-for-android
# Generating JSON report for :xearth
# Generating JSON report for :xenia
# Generating JSON report for :xia-express
# Generating JSON report for :xmouse
# Generating JSON report for :xoverrideheadphonejackdetection
# Generating JSON report for :xposed-downloader
# Generating JSON report for :xposed-installer
# Generating JSON report for :xprivacylua
# Generating JSON report for :xskat
# Generating JSON report for :xtheremotx
# Generating JSON report for :xvii-messenger-for-vk
# Generating JSON report for :yaaic
# Generating JSON report for :yacguide
# Generating JSON report for :yacguide-dev
# Generating JSON report for :yahtzee-dicer
# Generating JSON report for :yalp-store
# Generating JSON report for :yalp-store-fork
# Generating JSON report for :yarc
# Generating JSON report for :yarr
# Generating JSON report for :yashlang
# Generating JSON report for :yggdrasil
# Generating JSON report for :yidkey-kd
# Generating JSON report for :ykdroid
# Generating JSON report for :yokatta
# Generating JSON report for :yoke
# Generating JSON report for :your-local-weather
# Generating JSON report for :youtube-listing-app
# Generating JSON report for :youtube-stream
# Generating JSON report for :yubiclip
# Generating JSON report for :yubico-authenticator
# Generating JSON report for :yucata-envoy
# Generating JSON report for :zapp
# Generating JSON report for :zephyrlogger
