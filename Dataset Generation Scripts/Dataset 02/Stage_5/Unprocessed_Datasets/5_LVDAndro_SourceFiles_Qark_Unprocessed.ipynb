# %%
import pandas as pd

# %%
csv_1_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_1_Round.csv"
csv_2_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_2_Round.csv"
csv_3_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_3_Round.csv"
csv_4_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_4_Round.csv"
csv_5_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_5_Round.csv"
csv_6_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_6_Round.csv"
csv_7_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_7_Round.csv"

# %%
vulnerability_df_1_round = pd.read_csv(csv_1_round)

# %%
vulnerability_df_1_round.columns
# Out:
# Index(['Unnamed: 0', 'app_name', 'category', 'severity', 'qark_name', 'Code',
#        'CWE_ID', 'CWE_Desc', 'Vulnerability_status'],
#       dtype='object')

# %%
vulnerability_df_1_round.loc[vulnerability_df_1_round['Vulnerability_status'] == 1].head().fillna("")
# Out:
#      Unnamed: 0   app_name category severity                      qark_name  \
# 10           10    %24hell     file     INFO       Hardcoded HTTP url found
# 41           41    %24hell  webview  WARNING  Javascript enabled in Webview
# 206         206  1x1-clock     file  WARNING                  Logging found
# 208         208  1x1-clock     file     INFO       Hardcoded HTTP url found
# 276         276  1x1-clock     file  WARNING                  Logging found
#
#                                                   Code   CWE_ID  \
# 10                                                   *  CWE-312
# 41   binding.onlineScriptingWeb.getSettings().setJa...  CWE-939
# 206  Log.d(TAG, String.format("Name not found: %s",...  CWE-532
# 208                                                /**  CWE-312
# 276            Log.d(TAG, "Failed to parse color", e);  CWE-532
#
#                                               CWE_Desc  Vulnerability_status
# ...

# %%
vulnerability_df_1_round = pd.read_csv(csv_1_round, low_memory=False).fillna("")

vulnerability_df_2_round = pd.read_csv(csv_2_round, low_memory=False).fillna("")

vulnerability_df_3_round = pd.read_csv(csv_3_round, low_memory=False).fillna("")

vulnerability_df_4_round = pd.read_csv(csv_4_round, low_memory=False).fillna("")

vulnerability_df_5_round = pd.read_csv(csv_5_round, low_memory=False).fillna("")

vulnerability_df_6_round = pd.read_csv(csv_6_round, low_memory=False).fillna("")

vulnerability_df_7_round = pd.read_csv(csv_7_round, low_memory=False).fillna("")



vulnerability_df= pd.concat([vulnerability_df_1_round, vulnerability_df_2_round, vulnerability_df_3_round, vulnerability_df_4_round, vulnerability_df_5_round, vulnerability_df_6_round, vulnerability_df_7_round], ignore_index=True)

# %%
vulnerability_df
# Out:
#          Unnamed: 0        app_name category severity qark_name  \
# 0                 0         %24hell
# 1                 1         %24hell
# 2                 2         %24hell
# 3                 3         %24hell
# 4                 4         %24hell
# ...             ...             ...      ...      ...       ...
# 4151069      126161  weather-widget
# 4151070      126162  weather-widget
# 4151071      126163  weather-widget
# 4151072      126164  weather-widget
# 4151073      126165  weather-widget
#
#                                                       Code CWE_ID CWE_Desc  \
# 0                        package in.ac.dducollegedu.shell;
# 1
# 2                          import android.content.Context;
# 3        import androidx.test.platform.app.Instrumentat...
# 4        import androidx.test.ext.junit.runners.Android...
# ...                                                    ...    ...      ...
# 4151069  public static ArrayList<WeatherStation> fromJs...
# ...

# %%
del vulnerability_df['Unnamed: 0']

# %%
del vulnerability_df['app_name']

# %%
vulnerability_df=vulnerability_df.rename(columns = {'qark_name':'Description'})

# %%
vulnerability_df=vulnerability_df.rename(columns = {'severity':'Severity'})

# %%
vulnerability_df
# Out:
#         category Severity Description  \
# 0
# 1
# 2
# 3
# 4
# ...          ...      ...         ...
# 4151069
# 4151070
# 4151071
# 4151072
# 4151073
#
#                                                       Code CWE_ID CWE_Desc  \
# 0                        package in.ac.dducollegedu.shell;
# 1
# 2                          import android.content.Context;
# 3        import androidx.test.platform.app.Instrumentat...
# 4        import androidx.test.ext.junit.runners.Android...
# ...                                                    ...    ...      ...
# 4151069  public static ArrayList<WeatherStation> fromJs...
# 4151070  ArrayList<WeatherStation> weatherStations = ne...
# 4151071   for (int i = 0; i < jsonObjects.length(); i++) {
# 4151072  weatherStations.add(new WeatherStation(jsonObj...
# 4151073                            return weatherStations;
#
#          Vulnerability_status
# 0                           0
# 1                           0
# 2                           0
# ...

# %%
vulnerability_df=vulnerability_df.drop_duplicates(subset=['Code', 'CWE_ID'], keep='first')

# %%
vulnerability_df.reset_index(inplace=True)
vulnerability_df = vulnerability_df.rename(columns = {'index':'index'})

# %%
vulnerability_df
# Out:
#            index category Severity Description  \
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...      ...      ...         ...
# 3901784  4151069
# 3901785  4151070
# 3901786  4151071
# 3901787  4151072
# 3901788  4151073
#
#                                                       Code CWE_ID CWE_Desc  \
# 0                        package in.ac.dducollegedu.shell;
# 1
# 2                          import android.content.Context;
# 3        import androidx.test.platform.app.Instrumentat...
# 4        import androidx.test.ext.junit.runners.Android...
# ...                                                    ...    ...      ...
# 3901784  public static ArrayList<WeatherStation> fromJs...
# 3901785  ArrayList<WeatherStation> weatherStations = ne...
# 3901786   for (int i = 0; i < jsonObjects.length(); i++) {
# 3901787  weatherStations.add(new WeatherStation(jsonObj...
# ...

# %%
vulnerability_df.to_csv("LVDAndro_SourceFiles_Qark_Unprocessed.csv", index=False)
