# %%
import pandas as pd

# %%
csv_1_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_Files_Processed_Dataset_1_Round.csv"
csv_2_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_Files_Processed_Dataset_2_Round.csv"
csv_3_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_Files_Processed_Dataset_3_Round.csv"
csv_4_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_Files_Processed_Dataset_4_Round.csv"
csv_5_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_Files_Processed_Dataset_5_Round.csv"
csv_6_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_Files_Processed_Dataset_6_Round.csv"
csv_7_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_Files_Processed_Dataset_7_Round.csv"

# %%
vulnerability_df_1_round = pd.read_csv(csv_1_round)

# %%
vulnerability_df_1_round.columns
# Out:
# Index(['ID', 'Description', 'Type', 'Pattern', 'Code', 'Severity',
#        'Input Case', 'CVSS', 'CWE_ID', 'CWE_Desc', 'OWASP_Mobile',
#        'OWSAP_MASVS', 'Reference', 'Vulnerability_status', 'processed_code'],
#       dtype='object')

# %%
vulnerability_df_1_round.loc[vulnerability_df_1_round['Vulnerability_status'] == 1].head().fillna("")
# Out:
#                         ID                                        Description  \
# 80         android_logging  The App logs information. Sensitive informatio...
# 304        android_logging  The App logs information. Sensitive informatio...
# 308        android_logging  The App logs information. Sensitive informatio...
# 332  android_write_app_dir  App can write to App Directory. Sensitive Info...
# 516        android_logging  The App logs information. Sensitive informatio...
#
#         Type                                            Pattern  \
# 80     Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 304    Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 308    Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 332  RegexOr         ['MODE_PRIVATE', 'Context\\.MODE_PRIVATE']
# 516    Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
#
#                                                   Code Severity Input Case  \
# ...

# %%
vulnerability_df_1_round = pd.read_csv(csv_1_round, low_memory=False).fillna("")

vulnerability_df_2_round = pd.read_csv(csv_2_round, low_memory=False).fillna("")

vulnerability_df_3_round = pd.read_csv(csv_3_round, low_memory=False).fillna("")

vulnerability_df_4_round = pd.read_csv(csv_4_round, low_memory=False).fillna("")

vulnerability_df_5_round = pd.read_csv(csv_5_round, low_memory=False).fillna("")

vulnerability_df_6_round = pd.read_csv(csv_6_round, low_memory=False).fillna("")

vulnerability_df_7_round = pd.read_csv(csv_7_round, low_memory=False).fillna("")



vulnerability_df= pd.concat([vulnerability_df_1_round, vulnerability_df_2_round, vulnerability_df_3_round, vulnerability_df_4_round, vulnerability_df_5_round, vulnerability_df_6_round, vulnerability_df_7_round], ignore_index=True)

# %%
vulnerability_df
# Out:
#                                   ID  \
# 0
# 1
# 2
# 3
# 4
# ...                              ...
# 2215096
# 2215097
# 2215098  android_read_write_external
# 2215099
# 2215100
#
#                                                Description     Type  \
# 0
# 1
# 2
# 3
# 4
# ...                                                    ...      ...
# 2215096
# 2215097
# 2215098  App can read/write to External Storage. Any Ap...  RegexOr
# 2215099
# 2215100
#
#                                                    Pattern  \
# 0
# 1
# 2
# 3
# 4
# ...                                                    ...
# 2215096
# 2215097
# 2215098  ['\\.getExternalStorage', '\\.getExternalFiles...
# 2215099
# 2215100
#
#                                                       Code Severity  \
# 0                       // Copyright 2019 Matthew Chandler
# 1
# 2                          package org.mattvchandler.a2050
# 3                   import android.animation.ArgbEvaluator
# ...

# %%
vulnerability_df=vulnerability_df.drop_duplicates(subset=['processed_code', 'CWE_ID'], keep='first')

# %%
del vulnerability_df['ID']

# %%
vulnerability_df.reset_index(inplace=True)
vulnerability_df = vulnerability_df.rename(columns = {'index':'index'})

# %%
vulnerability_df
# Out:
#            index                                        Description     Type  \
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...                                                ...      ...
# 1930469  2215094  The App logs information. Sensitive informatio...    Regex
# 1930470  2215095
# 1930471  2215098  App can read/write to External Storage. Any Ap...  RegexOr
# 1930472  2215099
# 1930473  2215100
#
#                                                    Pattern  \
# 0
# 1
# 2
# 3
# 4
# ...                                                    ...
# 1930469  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 1930470
# 1930471  ['\\.getExternalStorage', '\\.getExternalFiles...
# 1930472
# 1930473
#
#                                                       Code Severity  \
# 0                       // Copyright 2019 Matthew Chandler
# 1
# 2                          package org.mattvchandler.a2050
# ...

# %%
vulnerability_df.to_csv("LVDAndro_SourceFiles_MobSF_Processed.csv", index=False)
