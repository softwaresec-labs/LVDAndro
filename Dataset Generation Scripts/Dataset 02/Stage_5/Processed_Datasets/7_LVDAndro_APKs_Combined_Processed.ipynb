# %%
import pandas as pd

# %%
MobSF_csv_1_round_No_Source = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_No_Source_Processed_Dataset_1_Round.csv"
MobSF_csv_2_round_No_Source = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_No_Source_Processed_Dataset_2_Round.csv"

MobSF_csv_1_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_App_Processed_Dataset_1_Round.csv"
MobSF_csv_2_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_App_Processed_Dataset_2_Round.csv"
MobSF_csv_3_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_App_Processed_Dataset_3_Round.csv"
MobSF_csv_4_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_App_Processed_Dataset_4_Round.csv"
MobSF_csv_5_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_App_Processed_Dataset_5_Round.csv"
MobSF_csv_6_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_App_Processed_Dataset_6_Round.csv"
MobSF_csv_7_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_App_Processed_Dataset_7_Round.csv"

Qark_csv_1_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_App_Processed_Dataset_1_Round.csv"
Qark_csv_2_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_App_Processed_Dataset_2_Round.csv"
Qark_csv_3_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_App_Processed_Dataset_3_Round.csv"
Qark_csv_4_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_App_Processed_Dataset_4_Round.csv"
Qark_csv_5_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_App_Processed_Dataset_5_Round.csv"
Qark_csv_6_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_App_Processed_Dataset_6_Round.csv"
Qark_csv_7_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_App_Processed_Dataset_7_Round.csv"

# %%
MobSF_vulnerability_df_1_round_No_Source = pd.read_csv(MobSF_csv_1_round_No_Source, low_memory=False).fillna("")
MobSF_vulnerability_df_2_round_No_Source = pd.read_csv(MobSF_csv_2_round_No_Source, low_memory=False).fillna("")

MobSF_vulnerability_df_1_round = pd.read_csv(MobSF_csv_1_round, low_memory=False).fillna("")
MobSF_vulnerability_df_2_round = pd.read_csv(MobSF_csv_2_round, low_memory=False).fillna("")
MobSF_vulnerability_df_3_round = pd.read_csv(MobSF_csv_3_round, low_memory=False).fillna("")
MobSF_vulnerability_df_4_round = pd.read_csv(MobSF_csv_4_round, low_memory=False).fillna("")
MobSF_vulnerability_df_5_round = pd.read_csv(MobSF_csv_5_round, low_memory=False).fillna("")
MobSF_vulnerability_df_6_round = pd.read_csv(MobSF_csv_6_round, low_memory=False).fillna("")
MobSF_vulnerability_df_7_round = pd.read_csv(MobSF_csv_7_round, low_memory=False).fillna("")

vulnerability_df_MobSF= pd.concat([MobSF_vulnerability_df_1_round_No_Source, MobSF_vulnerability_df_2_round_No_Source,MobSF_vulnerability_df_1_round, MobSF_vulnerability_df_2_round, MobSF_vulnerability_df_3_round, MobSF_vulnerability_df_4_round, MobSF_vulnerability_df_5_round, MobSF_vulnerability_df_6_round, MobSF_vulnerability_df_7_round], ignore_index=True)
vulnerability_df_MobSF=vulnerability_df_MobSF.drop_duplicates(subset=['Code', 'CWE_ID'], keep='first')

Qark_vulnerability_df_1_round = pd.read_csv(Qark_csv_1_round, low_memory=False).fillna("")
Qark_vulnerability_df_2_round = pd.read_csv(Qark_csv_2_round, low_memory=False).fillna("")
Qark_vulnerability_df_3_round = pd.read_csv(Qark_csv_3_round, low_memory=False).fillna("")
Qark_vulnerability_df_4_round = pd.read_csv(Qark_csv_4_round, low_memory=False).fillna("")
Qark_vulnerability_df_5_round = pd.read_csv(Qark_csv_5_round, low_memory=False).fillna("")
Qark_vulnerability_df_6_round = pd.read_csv(Qark_csv_6_round, low_memory=False).fillna("")
Qark_vulnerability_df_7_round = pd.read_csv(Qark_csv_7_round, low_memory=False).fillna("")


vulnerability_df_Qark= pd.concat([Qark_vulnerability_df_1_round, Qark_vulnerability_df_2_round, Qark_vulnerability_df_3_round, Qark_vulnerability_df_4_round, Qark_vulnerability_df_5_round, Qark_vulnerability_df_6_round, Qark_vulnerability_df_7_round], ignore_index=True)
vulnerability_df_Qark=vulnerability_df_Qark.drop_duplicates(subset=['Code', 'CWE_ID'], keep='first')

# %%
vulnerability_df_MobSF
# Out:
#         ID Description Type Pattern  \
# 0
# 1
# 2
# 3
# 4
# ...     ..         ...  ...     ...
# 7778587
# 7778589
# 7778590
# 7778693
# 7778877
#
#                                                       Code Severity  \
# 0                             package de.cketti.changelog;
# 1
# 2                          import android.content.Context;
# 3                import android.content.SharedPreferences;
# 4                   import android.content.pm.PackageInfo;
# ...                                                    ...      ...
# 7778587  ClipboardListener.this.lambda$null$0$Clipboard...
# 7778589  clipboardManager.addPrimaryClipChangedListener...
# 7778590  public /* synthetic */ void lambda$null$0$Clip...
# 7778693                                   segment.pos = i;
# 7778877  Log.e(TAG, "replyToNotification error: " + e.g...
#
#         Input Case CVSS CWE_ID CWE_Desc OWASP_Mobile OWSAP_MASVS Reference  \
# 0
# 1
# 2
# 3
# 4
# ...            ...  ...    ...      ...          ...         ...       ...
# 7778587
# 7778589
# 7778590
# 7778693
# 7778877
#
#          Vulnerability_status  \
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0
# ...                       ...
# 7778587                     0
# 7778589                     0
# 7778590                     0
# 7778693                     0
# 7778877                     0
#
#                                             processed_code
# 0                             package de.cketti.changelog;
# 1
# 2                          import android.content.Context;
# 3                import android.content.SharedPreferences;
# 4                   import android.content.pm.PackageInfo;
# ...                                                    ...
# 7778587  ClipboardListener.this.lambda$null$0$Clipboard...
# 7778589  clipboardManager.addPrimaryClipChangedListener...
# 7778590  //user_comment void lambda$null$0$ClipboardLis...
# 7778693                                   segment.pos = i;
# 7778877           Log.e(TAG, "user_str" + e.getMessage());
#
# [5547672 rows x 15 columns]

# %%
vulnerability_df_MobSF.columns
# Out:
# Index(['ID', 'Description', 'Type', 'Pattern', 'Code', 'Severity',
#        'Input Case', 'CVSS', 'CWE_ID', 'CWE_Desc', 'OWASP_Mobile',
#        'OWSAP_MASVS', 'Reference', 'Vulnerability_status', 'processed_code'],
#       dtype='object')

# %%
del vulnerability_df_MobSF['ID']

# %%
vulnerability_df_Qark
# Out:
#           Unnamed: 0  app_name category severity qark_name  \
# 0                  0   %24hell
# 1                  1   %24hell
# 2                  2   %24hell
# 3                  3   %24hell
# 4                  4   %24hell
# ...              ...       ...      ...      ...       ...
# 11658361     5295242  wormhole
# 11658362     5295243  wormhole
# 11658363     5295244  wormhole
# 11658364     5295245  wormhole
# 11658366     5295256  wormhole
#
#                                                        Code CWE_ID CWE_Desc  \
# 0                              package androidx.preference;
# 1
# 2                                 import a.a.a.a.class_698;
# 3                           import android.content.Context;
# 4                    import android.content.res.TypedArray;
# ...                                                     ...    ...      ...
# 11658361        pointerId2 = motionEvent.getPointerId(n10);
# 11658362    n8 = motionEvent.getX(n10) / SDLSurface.mWidth;
# 11658363   n9 = motionEvent.getY(n10) / SDLSurface.mHeight;
# 11658364          pressure3 = motionEvent.getPressure(n10);
# 11658366  SDLActivity.onNativeTouch(deviceId, n, 1, n6, ...
#
#           Vulnerability_status  \
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0
# ...                        ...
# 11658361                     0
# 11658362                     0
# 11658363                     0
# 11658364                     0
# 11658366                     0
#
#                                              processed_code
# 0                              package androidx.preference;
# 1
# 2                                 import a.a.a.a.class_698;
# 3                           import android.content.Context;
# 4                    import android.content.res.TypedArray;
# ...                                                     ...
# 11658361        pointerId2 = motionEvent.getPointerId(n10);
# 11658362    n8 = motionEvent.getX(n10) / SDLSurface.mWidth;
# 11658363   n9 = motionEvent.getY(n10) / SDLSurface.mHeight;
# 11658364          pressure3 = motionEvent.getPressure(n10);
# 11658366  SDLActivity.onNativeTouch(deviceId, n, 1, n6, ...
#
# [7379976 rows x 10 columns]

# %%
vulnerability_df_Qark.columns
# Out:
# Index(['Unnamed: 0', 'app_name', 'category', 'severity', 'qark_name', 'Code',
#        'CWE_ID', 'CWE_Desc', 'Vulnerability_status', 'processed_code'],
#       dtype='object')

# %%
del vulnerability_df_Qark['Unnamed: 0']
del vulnerability_df_Qark['app_name']

# %%
vulnerability_df=pd.concat([vulnerability_df_MobSF, vulnerability_df_Qark], ignore_index=True).fillna("")

# %%
vulnerability_df
# Out:
#          Description Type Pattern  \
# 0
# 1
# 2
# 3
# 4
# ...              ...  ...     ...
# 12927643
# 12927644
# 12927645
# 12927646
# 12927647
#
#                                                        Code Severity  \
# 0                              package de.cketti.changelog;
# 1
# 2                           import android.content.Context;
# 3                 import android.content.SharedPreferences;
# 4                    import android.content.pm.PackageInfo;
# ...                                                     ...      ...
# 12927643        pointerId2 = motionEvent.getPointerId(n10);
# 12927644    n8 = motionEvent.getX(n10) / SDLSurface.mWidth;
# 12927645   n9 = motionEvent.getY(n10) / SDLSurface.mHeight;
# 12927646          pressure3 = motionEvent.getPressure(n10);
# 12927647  SDLActivity.onNativeTouch(deviceId, n, 1, n6, ...
#
#          Input Case CVSS CWE_ID CWE_Desc OWASP_Mobile OWSAP_MASVS Reference  \
# 0
# 1
# 2
# 3
# 4
# ...             ...  ...    ...      ...          ...         ...       ...
# 12927643
# 12927644
# 12927645
# 12927646
# 12927647
#
#           Vulnerability_status  \
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0
# ...                        ...
# 12927643                     0
# 12927644                     0
# 12927645                     0
# 12927646                     0
# 12927647                     0
#
#                                              processed_code category severity  \
# 0                              package de.cketti.changelog;
# 1
# 2                           import android.content.Context;
# 3                 import android.content.SharedPreferences;
# 4                    import android.content.pm.PackageInfo;
# ...                                                     ...      ...      ...
# 12927643        pointerId2 = motionEvent.getPointerId(n10);
# 12927644    n8 = motionEvent.getX(n10) / SDLSurface.mWidth;
# 12927645   n9 = motionEvent.getY(n10) / SDLSurface.mHeight;
# 12927646          pressure3 = motionEvent.getPressure(n10);
# 12927647  SDLActivity.onNativeTouch(deviceId, n, 1, n6, ...
#
#          qark_name
# 0
# 1
# 2
# 3
# 4
# ...            ...
# 12927643
# 12927644
# 12927645
# 12927646
# 12927647
#
# [12927648 rows x 17 columns]

# %%
vulnerability_df=vulnerability_df.drop_duplicates(subset=['processed_code', 'CWE_ID'], keep='first')

# %%
vulnerability_df.reset_index(inplace=True)
vulnerability_df = vulnerability_df.rename(columns = {'index':'index'})

# %%
vulnerability_df
# Out:
#              index Description Type Pattern  \
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
# ...            ...         ...  ...     ...
# 12356286  12927643
# 12356287  12927644
# 12356288  12927645
# 12356289  12927646
# 12356290  12927647
#
#                                                        Code Severity  \
# 0                              package de.cketti.changelog;
# 1
# 2                           import android.content.Context;
# 3                 import android.content.SharedPreferences;
# 4                    import android.content.pm.PackageInfo;
# ...                                                     ...      ...
# 12356286        pointerId2 = motionEvent.getPointerId(n10);
# 12356287    n8 = motionEvent.getX(n10) / SDLSurface.mWidth;
# 12356288   n9 = motionEvent.getY(n10) / SDLSurface.mHeight;
# 12356289          pressure3 = motionEvent.getPressure(n10);
# 12356290  SDLActivity.onNativeTouch(deviceId, n, 1, n6, ...
#
#          Input Case CVSS CWE_ID CWE_Desc OWASP_Mobile OWSAP_MASVS Reference  \
# 0
# 1
# 2
# 3
# 4
# ...             ...  ...    ...      ...          ...         ...       ...
# 12356286
# 12356287
# 12356288
# 12356289
# 12356290
#
#           Vulnerability_status  \
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0
# ...                        ...
# 12356286                     0
# 12356287                     0
# 12356288                     0
# 12356289                     0
# 12356290                     0
#
#                                              processed_code category severity  \
# 0                              package de.cketti.changelog;
# 1
# 2                           import android.content.Context;
# 3                 import android.content.SharedPreferences;
# 4                    import android.content.pm.PackageInfo;
# ...                                                     ...      ...      ...
# 12356286        pointerId2 = motionEvent.getPointerId(n10);
# 12356287    n8 = motionEvent.getX(n10) / SDLSurface.mWidth;
# 12356288   n9 = motionEvent.getY(n10) / SDLSurface.mHeight;
# 12356289          pressure3 = motionEvent.getPressure(n10);
# 12356290  SDLActivity.onNativeTouch(deviceId, n, 1, n6, ...
#
#          qark_name
# 0
# 1
# 2
# 3
# 4
# ...            ...
# 12356286
# 12356287
# 12356288
# 12356289
# 12356290
#
# [12356291 rows x 18 columns]

# %%
vulnerability_df.to_csv("LVDAndro_APKs_Combined_Processed.csv", index=False)
