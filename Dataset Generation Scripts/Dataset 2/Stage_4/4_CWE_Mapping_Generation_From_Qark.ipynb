# %%
import pandas as pd

# %%
APPLICATION_BASE_PATH = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset"
round_path = APPLICATION_BASE_PATH+"/7_Round_Qark"
data_csv = round_path+"/7_Round_Files_Qark_Analysis_without_CWE.csv"
cwe_mapping = APPLICATION_BASE_PATH+"/QARK Vulnerabilities mapping.csv"
cwe_mapped_csv = round_path+"/7_Round_Files_Qark_Analysis_CWE_mapped.csv"

# %%
df_data = pd.read_csv(data_csv)

# %%
df_data.head()
# Out:
#               app_name category severity  \
# 0  us-travel-converter     file     INFO
# 1  us-travel-converter     file     INFO
# 2             userland     file     INFO
# 3             userland     file     INFO
# 4             userland     file     INFO
#
#                                          description  \
# 0  Application contains hardcoded HTTP url: http:...
# 1  Application contains hardcoded HTTP url: http:...
# 2  Please confirm and investigate the API key to ...
# 3  Please confirm and investigate the API key to ...
# 4  Please confirm and investigate the API key to ...
#
#                        name line_number  \
# 0  Hardcoded HTTP url found     [32_ 0]
# 1  Hardcoded HTTP url found     [37_ 0]
# 2   Potential API Key found     [83_ 0]
# 3   Potential API Key found    [211_ 0]
# 4   Potential API Key found    [125_ 0]
#
#                                          file_object apk_exploit_dict
# 0  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None
# 1  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None
# 2  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None
# 3  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None
# 4  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None

# %%
df_data.set_index('name')
df_data.head()
# Out:
#               app_name category severity  \
# 0  us-travel-converter     file     INFO
# 1  us-travel-converter     file     INFO
# 2             userland     file     INFO
# 3             userland     file     INFO
# 4             userland     file     INFO
#
#                                          description  \
# 0  Application contains hardcoded HTTP url: http:...
# 1  Application contains hardcoded HTTP url: http:...
# 2  Please confirm and investigate the API key to ...
# 3  Please confirm and investigate the API key to ...
# 4  Please confirm and investigate the API key to ...
#
#                        name line_number  \
# 0  Hardcoded HTTP url found     [32_ 0]
# 1  Hardcoded HTTP url found     [37_ 0]
# 2   Potential API Key found     [83_ 0]
# 3   Potential API Key found    [211_ 0]
# 4   Potential API Key found    [125_ 0]
#
#                                          file_object apk_exploit_dict
# 0  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None
# 1  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None
# 2  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None
# 3  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None
# 4  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None

# %%
df_data.shape
# Out:
# (14668, 8)

# %%
df_cwe_mapping = pd.read_csv(cwe_mapping)

# %%
df_cwe_mapping.head()
# Out:
#     Category                                               name   CWE_ID  \
# 0  broadcast                   Dynamic broadcast receiver found  CWE-925
# 1  broadcast                 Send Broadcast Receiver Permission  CWE-925
# 2  broadcast          Broadcast sent without receiverPermission  CWE-925
# 3  broadcast  Broadcast sent with receiverPermission with mi...  CWE-927
# 4  broadcast             Broadcast sent with receiverPermission  CWE-927
#
#                                             CWE_Desc
# 0  Improper Verification of Intent by Broadcast R...
# 1  Improper Verification of Intent by Broadcast R...
# 2  Improper Verification of Intent by Broadcast R...
# 3  Use of Implicit Intent for Sensitive Communica...
# 4  Use of Implicit Intent for Sensitive Communica...

# %%
df_cwe_mapping = df_cwe_mapping[['name','CWE_ID','CWE_Desc']]
df_cwe_mapping.set_index('name')
df_cwe_mapping.head()
# Out:
#                                                 name   CWE_ID  \
# 0                   Dynamic broadcast receiver found  CWE-925
# 1                 Send Broadcast Receiver Permission  CWE-925
# 2          Broadcast sent without receiverPermission  CWE-925
# 3  Broadcast sent with receiverPermission with mi...  CWE-927
# 4             Broadcast sent with receiverPermission  CWE-927
#
#                                             CWE_Desc
# 0  Improper Verification of Intent by Broadcast R...
# 1  Improper Verification of Intent by Broadcast R...
# 2  Improper Verification of Intent by Broadcast R...
# 3  Use of Implicit Intent for Sensitive Communica...
# 4  Use of Implicit Intent for Sensitive Communica...

# %%
df_cwe_mapping.shape
# Out:
# (51, 3)

# %%
cwe_Qark_dictionary = df_cwe_mapping.to_dict('dict')
name_Qark_dictionary = cwe_Qark_dictionary.get("name")
cwe_ID_Qark_dictionary = cwe_Qark_dictionary.get("CWE_ID")
cwe_Desc_Qark_dictionary = cwe_Qark_dictionary.get("CWE_Desc")

# %%
def get_cwe_detail(name):
    
    key_list = list(name_Qark_dictionary.keys())
    val_list = list(name_Qark_dictionary.values())

    position = val_list.index(name)
    
    return str(cwe_ID_Qark_dictionary.get(position)), str(cwe_Desc_Qark_dictionary.get(position))

# %%
df_data.head()
# Out:
#               app_name category severity  \
# 0  us-travel-converter     file     INFO
# 1  us-travel-converter     file     INFO
# 2             userland     file     INFO
# 3             userland     file     INFO
# 4             userland     file     INFO
#
#                                          description  \
# 0  Application contains hardcoded HTTP url: http:...
# 1  Application contains hardcoded HTTP url: http:...
# 2  Please confirm and investigate the API key to ...
# 3  Please confirm and investigate the API key to ...
# 4  Please confirm and investigate the API key to ...
#
#                        name line_number  \
# 0  Hardcoded HTTP url found     [32_ 0]
# 1  Hardcoded HTTP url found     [37_ 0]
# 2   Potential API Key found     [83_ 0]
# 3   Potential API Key found    [211_ 0]
# 4   Potential API Key found    [125_ 0]
#
#                                          file_object apk_exploit_dict
# 0  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None
# 1  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None
# 2  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None
# 3  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None
# 4  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None

# %%
for index,item in cwe_Qark_dictionary.get('name').items():
    name = item
    CWE_ID,CWE_desc = get_cwe_detail(item)
    df_data.loc[df_data.name == name, "CWE_ID"] = CWE_ID  
    df_data.loc[df_data.name == name, "CWE_Desc"] = CWE_desc

# %%
df_data.columns = ['app_name', 'category','severity','description','qark_name','line_number','file_object','apk_exploit_dict','CWE_ID','CWE_Desc']
df_data.head()
# Out:
#               app_name category severity  \
# 0  us-travel-converter     file     INFO
# 1  us-travel-converter     file     INFO
# 2             userland     file     INFO
# 3             userland     file     INFO
# 4             userland     file     INFO
#
#                                          description  \
# 0  Application contains hardcoded HTTP url: http:...
# 1  Application contains hardcoded HTTP url: http:...
# 2  Please confirm and investigate the API key to ...
# 3  Please confirm and investigate the API key to ...
# 4  Please confirm and investigate the API key to ...
#
#                   qark_name line_number  \
# 0  Hardcoded HTTP url found     [32_ 0]
# 1  Hardcoded HTTP url found     [37_ 0]
# 2   Potential API Key found     [83_ 0]
# 3   Potential API Key found    [211_ 0]
# 4   Potential API Key found    [125_ 0]
#
#                                          file_object apk_exploit_dict  \
# 0  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None
# 1  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None
# 2  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None
# 3  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None
# 4  I:\PhD\Model_Building\APKs_and_GitRepos\GITRep...             None
#
#     CWE_ID                                           CWE_Desc
# 0  CWE-312         Cleartext Storage of Sensitive Information
# 1  CWE-312         Cleartext Storage of Sensitive Information
# 2  CWE-200  Exposure of Sensitive Information to an Unauth...
# 3  CWE-200  Exposure of Sensitive Information to an Unauth...
# 4  CWE-200  Exposure of Sensitive Information to an Unauth...

# %%
df_data.to_csv(cwe_mapped_csv)
