# %%
import json
import requests
from requests_toolbelt.multipart.encoder import MultipartEncoder
import subprocess
import os
import json
import requests
import csv
import pandas as pd
import time
from datetime import datetime

# %%
IP_PORT = "127.0.0.1:8000"
SERVER = "http://"+IP_PORT
MOBSF_BASE_PATH = "D:/PhD/Model_Building/Scanners_and_Decompilers/Scanners/MobSF"
APIKEY = "4a9fc3e94941f832d40975a251056079c9be5406891a934ded21a3c0ecdc5119"

# %%
APPLICATION_BASE_PATH = "D:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/7_Round_MobSF"

#JSON_FILE_PATH = APPLICATION_BASE_PATH+"/Scanned_App_JSON_Files"
#SOURCE_FILE = "Scanned_App_Details.csv"
#SCAN_TYPE = "apk"
#TYPE = "Scanned_App"

JSON_FILE_PATH = APPLICATION_BASE_PATH+"/Scanned_Files_JSON_Files"
SOURCE_FILE = "Scanned_Files_Details.csv"
SCAN_TYPE = "studio" # for zip
TYPE = "Scanned_Files"

#JSON_FILE_PATH = APPLICATION_BASE_PATH+"/Scanned_No_Source_JSON_Files"
#SOURCE_FILE = "Scanned_No_Source_Details.csv"
#SCAN_TYPE = "apk"
#TYPE = "Scanned_No_Source"

# %%
def start_MobSF_server():
    os.chdir(MOBSF_BASE_PATH)
    command = 'start run.bat '+IP_PORT
    subprocess.call(command, shell = True)
    time.sleep(30)

# %%
def get_source_code(app_name, app_hash, source_file):    
    
    headers = {'Authorization': APIKEY}
    data = {"hash": app_hash , "type":SCAN_TYPE, "file": source_file}
    response = requests.post(SERVER + '/api/v1/view_source', data=data, headers=headers)   

    json_object = json.loads(response.text)

    source_code = json_object["data"]        

    java_file = open(app_name+".java", "wb")
    java_file.write(source_code.encode("utf-8"))
    java_file.close()    
    source_code_df=pd.read_csv(app_name+".java", encoding='utf-8', header=None, delimiter="\n",skip_blank_lines=False).fillna("")
    os.remove(app_name+".java")
    
    return source_code_df

# %%
def generate_vulnerable_dataset():   
    
    scan_details = pd.read_csv(APPLICATION_BASE_PATH+"/"+SOURCE_FILE)       
           
    vulberability_dataset = []  
    
    for index, row in scan_details.iterrows():
        try:
            app_name = str(row['app_name'])
            app_hash = str(row['app_hash'])       

            print("Generating vulnerability Dataset from app : "+app_name)

            json_file = open(JSON_FILE_PATH+'/'+app_name+'.json')
            code_analysis_json_obj = json.load(json_file)["code_analysis"]


            json_file.close()        

            #Iterating through each issue
            for each_android_issue in code_analysis_json_obj:
                try:
                    for each_files in code_analysis_json_obj[each_android_issue]["files"]:                        
                        try:
                            filepath = str(each_files)
                            code_lines_str_list = str(code_analysis_json_obj[each_android_issue]["files"][each_files]).split(",")
                            code_lines = list(map(int, code_lines_str_list))

                            for i in range(len(code_lines)):
                                code_lines[i] = code_lines[i] - 1

                            all_code_lines = get_source_code(app_name, app_hash, filepath)

                            for index, row in all_code_lines.iterrows():
                                vulnerability_status = 0
                                if index in code_lines:
                                    vulnerability_status = 1

                                code = str(row[0]).strip()                    
                                attr_id = ""
                                attr_description = ""
                                attr_type = ""
                                attr_pattern = ""
                                attr_severity = ""
                                attr_input_case = ""
                                attr_cvss = ""
                                attr_cwe_id = ""
                                attr_cwe_desc = ""
                                attr_owasp_mobile = ""
                                attr_masvs = ""
                                attr_ref = ""

                                if vulnerability_status == 1:                        
                                    metadata = code_analysis_json_obj[each_android_issue]["metadata"]
                                    attr_id = str(metadata["id"])
                                    attr_description = str(metadata["description"])
                                    attr_type = str(metadata["type"])
                                    attr_pattern = str(metadata["pattern"])
                                    attr_severity = str(metadata["severity"])
                                    attr_input_case = str(metadata["input_case"])
                                    attr_cvss = str(metadata["cvss"])
                                    attr_cwe = str(metadata["cwe"])
                                    attr_cwe_split = attr_cwe.split(" ")
                                    attr_cwe_id = attr_cwe_split[0]
                                    attr_cwe_desc = attr_cwe[len(attr_cwe_id)+1:]
                                    attr_owasp_mobile = str(metadata["owasp-mobile"])
                                    attr_masvs = str(metadata["masvs"])
                                    try:
                                        attr_ref = str(metadata["ref"])
                                    except:
                                        attr_ref=""

                                csv_data_row = [attr_id, attr_description, attr_type, attr_pattern, code, attr_severity,
                                                    attr_input_case, attr_cvss, attr_cwe_id, attr_cwe_desc,
                                                    attr_owasp_mobile, attr_masvs, attr_ref, vulnerability_status]

                                vulberability_dataset.append(csv_data_row)

                        except Exception as ef:
                            print(str(ef)+" : in file : "+each_files)
                            continue
                            
                except Exception as ei:
                    print(str(ei)+" : for android issue : "+ each_android_issue)
                    continue
                       
        except Exception as ej:
            print(str(ej)+ " : for json file : "+app_name+".json")
            continue

    #data frame to csv                
    header = ['ID', 'Description', 'Type', 'Pattern', 'Code', 'Severity', 'Input Case', 'CVSS', 'CWE_ID', 'CWE_Desc', 'OWASP_Mobile', 'OWSAP_MASVS', 'Reference', 'Vulnerability_status']
    vulberability_dataframe = pd.DataFrame(vulberability_dataset, columns = header)
    
    vulberability_dataframe.drop_duplicates(subset=['Code', 'CWE_ID'], inplace=True)
    
    date_time_now = str(datetime.now()).replace('-', '').replace(' ', '').replace(':', '').replace('.', '')
    vulberability_dataframe.to_csv(APPLICATION_BASE_PATH+"/"+TYPE+'_Unprocessed_Dataset_'+date_time_now+'.csv', sep=',', encoding='utf-8', index=False)

# %%
def execute_process():
    print("********************Dataset Generation Started**************************")
    #start_MobSF_server()
    generate_vulnerable_dataset()
    print("********************Dataset Generation Completed**************************")

# %%
execute_process()
# Out:
# ********************Dataset Generation Started**************************
# Generating vulnerability Dataset from app : us-travel-converter
# Generating vulnerability Dataset from app : userland
# Generating vulnerability Dataset from app : uuid-0xfd6f-scanner
# Generating vulnerability Dataset from app : v2ex
# Generating vulnerability Dataset from app : v2ray
# Generating vulnerability Dataset from app : vadret
# Generating vulnerability Dataset from app : valetudo-companion
# Generating vulnerability Dataset from app : vanilla-cover-fetcher
# Generating vulnerability Dataset from app : vanilla-lyrics-search
# Generating vulnerability Dataset from app : vanilla-metadata-fetch
# Generating vulnerability Dataset from app : vanilla-music
# Generating vulnerability Dataset from app : vanilla-tag-editor
# Generating vulnerability Dataset from app : varengold-activetan
# Generating vulnerability Dataset from app : vector-camera
# Generating vulnerability Dataset from app : vector-pinball
# Generating vulnerability Dataset from app : vedroid-events
# Generating vulnerability Dataset from app : velocity-calculator
# Generating vulnerability Dataset from app : verbiste-android
# 'code_analysis' : for json file : verbiste-android.json
# Generating vulnerability Dataset from app : veterondo
# Generating vulnerability Dataset from app : vibe
# Generating vulnerability Dataset from app : viborafeed
# Generating vulnerability Dataset from app : vibrato
# Generating vulnerability Dataset from app : video-transcoder
# Generating vulnerability Dataset from app : vigilante
# Generating vulnerability Dataset from app : vinyl-music-player
# Generating vulnerability Dataset from app : virtualsoftkeys
# Generating vulnerability Dataset from app : virtuosity
# Generating vulnerability Dataset from app : vlcfreemote
# Generating vulnerability Dataset from app : vlille-checker
# No columns to parse from file : in file : com/vlille/checker/utils/ViewUtils.java
# Generating vulnerability Dataset from app : vocabletrainer
# Generating vulnerability Dataset from app : voice-notify
# Generating vulnerability Dataset from app : voice-recorder
# Generating vulnerability Dataset from app : volta
# Generating vulnerability Dataset from app : volume-control-2
# Generating vulnerability Dataset from app : volumelockr
# Generating vulnerability Dataset from app : voucher-calc
# Generating vulnerability Dataset from app : vtu-cs-lab-manual
# Generating vulnerability Dataset from app : wairtonow
# Generating vulnerability Dataset from app : wallabag
# Generating vulnerability Dataset from app : walletcount
# Generating vulnerability Dataset from app : wallxth
# Generating vulnerability Dataset from app : wanidoku
# Generating vulnerability Dataset from app : warmshowers
# Generating vulnerability Dataset from app : warpclock
# Generating vulnerability Dataset from app : warpinator-for-android-unofficial
# Generating vulnerability Dataset from app : wasted
# Generating vulnerability Dataset from app : watertracker
# Generating vulnerability Dataset from app : waterydroid
# Generating vulnerability Dataset from app : watomatic-auto-reply-for-whatsapp
# Generating vulnerability Dataset from app : wator
# Generating vulnerability Dataset from app : watransmitter
# Generating vulnerability Dataset from app : watt
# Generating vulnerability Dataset from app : wave-lines
# Generating vulnerability Dataset from app : waveup-2
# Generating vulnerability Dataset from app : weather
# Generating vulnerability Dataset from app : weather-overview
# Generating vulnerability Dataset from app : weather-radar
# Generating vulnerability Dataset from app : weather-widget
# Generating vulnerability Dataset from app : weatherlog
# Generating vulnerability Dataset from app : web-media-share
# Generating vulnerability Dataset from app : webapps
# Generating vulnerability Dataset from app : webmon
# Generating vulnerability Dataset from app : website-monitor
# Generating vulnerability Dataset from app : webthingify
# Generating vulnerability Dataset from app : webtube
# Generating vulnerability Dataset from app : weechat
# Generating vulnerability Dataset from app : werewolf
# Generating vulnerability Dataset from app : wetter
# Generating vulnerability Dataset from app : whatsapp-twitch-stickers
# Generating vulnerability Dataset from app : whatsapp-web-to-go
# Generating vulnerability Dataset from app : whatsdeleted
# Generating vulnerability Dataset from app : who-has-my-stuff
# Generating vulnerability Dataset from app : wifi-analyzer
# Generating vulnerability Dataset from app : wifi-manager
# Generating vulnerability Dataset from app : wifi-matic
# Generating vulnerability Dataset from app : wifi-qr-code-creator
# Generating vulnerability Dataset from app : wifi-reminders
# Generating vulnerability Dataset from app : wifieapsimconf
# Generating vulnerability Dataset from app : wifikeyshare
# Generating vulnerability Dataset from app : wikipedia
# Generating vulnerability Dataset from app : wikipoff
# Generating vulnerability Dataset from app : wine-cellar
# Generating vulnerability Dataset from app : wire-secure-messenger
# Generating vulnerability Dataset from app : wirebug
# Generating vulnerability Dataset from app : wlanscanner
# Generating vulnerability Dataset from app : wonderdroid-x
# No columns to parse from file : in file : com/atelieryl/wonderdroid/Select.java
# No columns to parse from file : in file : com/atelieryl/wonderdroid/Select.java
# No columns to parse from file : in file : com/atelieryl/wonderdroid/Select.java
# No columns to parse from file : in file : com/atelieryl/wonderdroid/TouchInputHandler.java
# No columns to parse from file : in file : com/atelieryl/wonderdroid/utils/CpuUtils.java
# No columns to parse from file : in file : com/atelieryl/wonderdroid/utils/RomAdapter.java
# No columns to parse from file : in file : com/atelieryl/wonderdroid/WonderSwan.java
# No columns to parse from file : in file : com/atelieryl/wonderdroid/views/EmuView.java
# No columns to parse from file : in file : com/atelieryl/wonderdroid/views/HardwareButtonPreference.java
# No columns to parse from file : in file : com/atelieryl/wonderdroid/utils/ZipUtils.java
# No columns to parse from file : in file : com/atelieryl/wonderdroid/utils/ZipCache.java
# No columns to parse from file : in file : com/atelieryl/wonderdroid/Main.java
# No columns to parse from file : in file : com/atelieryl/wonderdroid/WonderDroid.java
# Generating vulnerability Dataset from app : word-of-the-day-learn-a-new-word-every-day
# Generating vulnerability Dataset from app : word-power-made-easy-2
# Generating vulnerability Dataset from app : word-value
# Generating vulnerability Dataset from app : wordbook-your-personal-dictionary
# Generating vulnerability Dataset from app : workoutlog
# Generating vulnerability Dataset from app : worktimer
# Generating vulnerability Dataset from app : world-scribe
# No columns to parse from file : in file : com/averi/worldscribe/utilities/tasks/GetConnectionsTask.java
# Generating vulnerability Dataset from app : wpgen
# Generating vulnerability Dataset from app : wrek-online
# Generating vulnerability Dataset from app : writeily-pro-2
# Generating vulnerability Dataset from app : wrong-pin-shutdown-2
# Generating vulnerability Dataset from app : wulkanowy
# Generating vulnerability Dataset from app : wx
# Generating vulnerability Dataset from app : wyfy
# Generating vulnerability Dataset from app : x11basic
# Generating vulnerability Dataset from app : xclipper-smart-clipboard-manager-for-android
# Generating vulnerability Dataset from app : xearth
# Generating vulnerability Dataset from app : xenia
# Generating vulnerability Dataset from app : xia-express
# Generating vulnerability Dataset from app : xmouse
# Generating vulnerability Dataset from app : xoverrideheadphonejackdetection
# Generating vulnerability Dataset from app : xposed-downloader
# Generating vulnerability Dataset from app : xposed-installer
# Generating vulnerability Dataset from app : xprivacylua
# Generating vulnerability Dataset from app : xskat
# Generating vulnerability Dataset from app : xtheremotx
# Generating vulnerability Dataset from app : xvii-messenger-for-vk
# Generating vulnerability Dataset from app : yaaic
# Generating vulnerability Dataset from app : yacguide
# Generating vulnerability Dataset from app : yacguide-dev
# Generating vulnerability Dataset from app : yahtzee-dicer
# Generating vulnerability Dataset from app : yalp-store
# Generating vulnerability Dataset from app : yalp-store-fork
# Generating vulnerability Dataset from app : yarc
# Generating vulnerability Dataset from app : yarr
# Generating vulnerability Dataset from app : yashlang
# Generating vulnerability Dataset from app : yggdrasil
# Generating vulnerability Dataset from app : yidkey-kd
# Generating vulnerability Dataset from app : ykdroid
# Generating vulnerability Dataset from app : yokatta
# Generating vulnerability Dataset from app : yoke
# Generating vulnerability Dataset from app : your-local-weather
# Generating vulnerability Dataset from app : youtube-listing-app
# Generating vulnerability Dataset from app : youtube-stream
# Generating vulnerability Dataset from app : yubiclip
# Generating vulnerability Dataset from app : yubico-authenticator
# Generating vulnerability Dataset from app : yucata-envoy
# Generating vulnerability Dataset from app : zapp
# Generating vulnerability Dataset from app : zephyrlogger
# ********************Dataset Generation Completed**************************
