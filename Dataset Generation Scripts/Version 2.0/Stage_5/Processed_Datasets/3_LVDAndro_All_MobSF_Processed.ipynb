# %%
import pandas as pd

# %%
csv_1_round_No_Source = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_No_Source_Processed_Dataset_1_Round.csv"
csv_2_round_No_Source = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_No_Source_Processed_Dataset_2_Round.csv"

csv_1_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_App_Processed_Dataset_1_Round.csv"
csv_2_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_App_Processed_Dataset_2_Round.csv"
csv_3_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_App_Processed_Dataset_3_Round.csv"
csv_4_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_App_Processed_Dataset_4_Round.csv"
csv_5_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_App_Processed_Dataset_5_Round.csv"
csv_6_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_App_Processed_Dataset_6_Round.csv"
csv_7_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_App_Processed_Dataset_7_Round.csv"

csv_1_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_Files_Processed_Dataset_1_Round.csv"
csv_2_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_Files_Processed_Dataset_2_Round.csv"
csv_3_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_Files_Processed_Dataset_3_Round.csv"
csv_4_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_Files_Processed_Dataset_4_Round.csv"
csv_5_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_Files_Processed_Dataset_5_Round.csv"
csv_6_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_Files_Processed_Dataset_6_Round.csv"
csv_7_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Processed_Datasets/Scanned_Files_Processed_Dataset_7_Round.csv"

# %%
vulnerability_df_1_round = pd.read_csv(csv_1_round)

# %%
vulnerability_df_1_round.columns
# Out:
# Index(['ID', 'Description', 'Type', 'Pattern', 'Code', 'Severity',
#        'Input Case', 'CVSS', 'CWE_ID', 'CWE_Desc', 'OWASP_Mobile',
#        'OWSAP_MASVS', 'Reference', 'Vulnerability_status', 'processed_code'],
#       dtype='object')

# %%
vulnerability_df_1_round.loc[vulnerability_df_1_round['Vulnerability_status'] == 1].head().fillna("")
# Out:
#                    ID                                        Description  \
# 175   android_logging  The App logs information. Sensitive informatio...
# 567   android_logging  The App logs information. Sensitive informatio...
# 1220  android_logging  The App logs information. Sensitive informatio...
# 1473  android_logging  The App logs information. Sensitive informatio...
# 1550  android_logging  The App logs information. Sensitive informatio...
#
#        Type                                            Pattern  \
# 175   Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 567   Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 1220  Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 1473  Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 1550  Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
#
#                                                    Code Severity Input Case  \
# ...

# %%
vulnerability_df_1_round_No_Source = pd.read_csv(csv_1_round_No_Source, low_memory=False).fillna("")

vulnerability_df_2_round_No_Source = pd.read_csv(csv_2_round_No_Source, low_memory=False).fillna("")

vulnerability_df_1_round = pd.read_csv(csv_1_round, low_memory=False).fillna("")

vulnerability_df_2_round = pd.read_csv(csv_2_round, low_memory=False).fillna("")

vulnerability_df_3_round = pd.read_csv(csv_3_round, low_memory=False).fillna("")

vulnerability_df_4_round = pd.read_csv(csv_4_round, low_memory=False).fillna("")

vulnerability_df_5_round = pd.read_csv(csv_5_round, low_memory=False).fillna("")

vulnerability_df_6_round = pd.read_csv(csv_6_round, low_memory=False).fillna("")

vulnerability_df_7_round = pd.read_csv(csv_7_round, low_memory=False).fillna("")


vulnerability_df_1_round_Files = pd.read_csv(csv_1_round_Files, low_memory=False).fillna("")

vulnerability_df_2_round_Files = pd.read_csv(csv_2_round_Files, low_memory=False).fillna("")

vulnerability_df_3_round_Files = pd.read_csv(csv_3_round_Files, low_memory=False).fillna("")

vulnerability_df_4_round_Files = pd.read_csv(csv_4_round_Files, low_memory=False).fillna("")

vulnerability_df_5_round_Files = pd.read_csv(csv_5_round_Files, low_memory=False).fillna("")

vulnerability_df_6_round_Files = pd.read_csv(csv_6_round_Files, low_memory=False).fillna("")

vulnerability_df_7_round_Files = pd.read_csv(csv_7_round_Files, low_memory=False).fillna("")





vulnerability_df= pd.concat([vulnerability_df_1_round_No_Source, vulnerability_df_2_round_No_Source,vulnerability_df_1_round, vulnerability_df_2_round, vulnerability_df_3_round, vulnerability_df_4_round, vulnerability_df_5_round, vulnerability_df_6_round, vulnerability_df_7_round,vulnerability_df_1_round_Files, vulnerability_df_2_round_Files, vulnerability_df_3_round_Files, vulnerability_df_4_round_Files, vulnerability_df_5_round_Files, vulnerability_df_6_round_Files, vulnerability_df_7_round_Files], ignore_index=True)

# %%
vulnerability_df
# Out:
#                                   ID  \
# 0
# 1
# 2
# 3
# 4
# ...                              ...
# 9993991
# 9993992
# 9993993  android_read_write_external
# 9993994
# 9993995
#
#                                                Description     Type  \
# 0
# 1
# 2
# 3
# 4
# ...                                                    ...      ...
# 9993991
# 9993992
# 9993993  App can read/write to External Storage. Any Ap...  RegexOr
# 9993994
# 9993995
#
#                                                    Pattern  \
# 0
# 1
# 2
# 3
# 4
# ...                                                    ...
# 9993991
# 9993992
# 9993993  ['\\.getExternalStorage', '\\.getExternalFiles...
# 9993994
# 9993995
#
#                                                       Code Severity  \
# 0                             package de.cketti.changelog;
# 1
# 2                          import android.content.Context;
# 3                import android.content.SharedPreferences;
# ...

# %%
vulnerability_df=vulnerability_df.drop_duplicates(subset=['processed_code', 'CWE_ID'], keep='first')

# %%
del vulnerability_df['ID']

# %%
vulnerability_df.reset_index(inplace=True)
vulnerability_df = vulnerability_df.rename(columns = {'index':'index'})

# %%
vulnerability_df
# Out:
#            index                                        Description   Type  \
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...                                                ...    ...
# 7201228  9993988
# 7201229  9993989  The App logs information. Sensitive informatio...  Regex
# 7201230  9993990
# 7201231  9993994
# 7201232  9993995
#
#                                                    Pattern  \
# 0
# 1
# 2
# 3
# 4
# ...                                                    ...
# 7201228
# 7201229  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 7201230
# 7201231
# 7201232
#
#                                                       Code Severity  \
# 0                             package de.cketti.changelog;
# 1
# 2                          import android.content.Context;
# 3                import android.content.SharedPreferences;
# 4                   import android.content.pm.PackageInfo;
# ...

# %%
vulnerability_df.to_csv("LVDAndro_All_MobSF_Processed.csv", index=False)
