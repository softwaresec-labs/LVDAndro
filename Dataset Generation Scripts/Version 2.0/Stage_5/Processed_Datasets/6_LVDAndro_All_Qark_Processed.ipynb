# %%
import pandas as pd

# %%
csv_1_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_App_Processed_Dataset_1_Round.csv"
csv_2_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_App_Processed_Dataset_2_Round.csv"
csv_3_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_App_Processed_Dataset_3_Round.csv"
csv_4_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_App_Processed_Dataset_4_Round.csv"
csv_5_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_App_Processed_Dataset_5_Round.csv"
csv_6_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_App_Processed_Dataset_6_Round.csv"
csv_7_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_App_Processed_Dataset_7_Round.csv"

csv_1_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_Files_Processed_Dataset_1_Round.csv"
csv_2_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_Files_Processed_Dataset_2_Round.csv"
csv_3_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_Files_Processed_Dataset_3_Round.csv"
csv_4_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_Files_Processed_Dataset_4_Round.csv"
csv_5_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_Files_Processed_Dataset_5_Round.csv"
csv_6_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_Files_Processed_Dataset_6_Round.csv"
csv_7_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Processed_Datasets/Scanned_Files_Processed_Dataset_7_Round.csv"

# %%
vulnerability_df_1_round = pd.read_csv(csv_1_round)

# %%
vulnerability_df_1_round.columns
# Out:
# Index(['Unnamed: 0', 'app_name', 'category', 'severity', 'qark_name', 'Code',
#        'CWE_ID', 'CWE_Desc', 'Vulnerability_status', 'processed_code'],
#       dtype='object')

# %%
vulnerability_df_1_round.loc[vulnerability_df_1_round['Vulnerability_status'] == 1].head().fillna("")
# Out:
#       Unnamed: 0 app_name category severity      qark_name  \
# 90            99  %24hell     file  WARNING  Logging found
# 145          163  %24hell     file  WARNING  Logging found
# 262          304  %24hell     file  WARNING  Logging found
# 1083        1165  %24hell     file  WARNING  Logging found
# 2623        2764  %24hell     file  WARNING  Logging found
#
#                                                    Code   CWE_ID  \
# 90    Log.w("ListPreference", "Setting a summary wit...  CWE-532
# 145   Log.w(c.b.a.a.e0.b.c, "Use a non-transparent c...  CWE-532
# 262   Log.w("ACTVAutoSizeHelper", var3.toString(), v...  CWE-532
# 1083          Log.w("ConstraintSet", var83.toString());  CWE-532
# 2623  Log.w(c.b.a.a.g0.g.z, "Compatibility shadow re...  CWE-532
#
#                                               CWE_Desc  Vulnerability_status  \
# 90    Insertion of Sensitive Information into Log File                     1
# ...

# %%
vulnerability_df_1_round = pd.read_csv(csv_1_round, low_memory=False).fillna("")

vulnerability_df_2_round = pd.read_csv(csv_2_round, low_memory=False).fillna("")

vulnerability_df_3_round = pd.read_csv(csv_3_round, low_memory=False).fillna("")

vulnerability_df_4_round = pd.read_csv(csv_4_round, low_memory=False).fillna("")

vulnerability_df_5_round = pd.read_csv(csv_5_round, low_memory=False).fillna("")

vulnerability_df_6_round = pd.read_csv(csv_6_round, low_memory=False).fillna("")

vulnerability_df_7_round = pd.read_csv(csv_7_round, low_memory=False).fillna("")


vulnerability_df_1_round_Files = pd.read_csv(csv_1_round_Files, low_memory=False).fillna("")

vulnerability_df_2_round_Files = pd.read_csv(csv_2_round_Files, low_memory=False).fillna("")

vulnerability_df_3_round_Files = pd.read_csv(csv_3_round_Files, low_memory=False).fillna("")

vulnerability_df_4_round_Files = pd.read_csv(csv_4_round_Files, low_memory=False).fillna("")

vulnerability_df_5_round_Files = pd.read_csv(csv_5_round_Files, low_memory=False).fillna("")

vulnerability_df_6_round_Files = pd.read_csv(csv_6_round_Files, low_memory=False).fillna("")

vulnerability_df_7_round_Files = pd.read_csv(csv_7_round_Files, low_memory=False).fillna("")





vulnerability_df= pd.concat([vulnerability_df_1_round, vulnerability_df_2_round, vulnerability_df_3_round, vulnerability_df_4_round, vulnerability_df_5_round, vulnerability_df_6_round, vulnerability_df_7_round,vulnerability_df_1_round_Files, vulnerability_df_2_round_Files, vulnerability_df_3_round_Files, vulnerability_df_4_round_Files, vulnerability_df_5_round_Files, vulnerability_df_6_round_Files, vulnerability_df_7_round_Files], ignore_index=True)

# %%
vulnerability_df
# Out:
#           Unnamed: 0        app_name category severity qark_name  \
# 0                  0         %24hell
# 1                  1         %24hell
# 2                  2         %24hell
# 3                  3         %24hell
# 4                  4         %24hell
# ...              ...             ...      ...      ...       ...
# 15288184      126161  weather-widget
# 15288185      126162  weather-widget
# 15288186      126163  weather-widget
# 15288187      126164  weather-widget
# 15288188      126165  weather-widget
#
#                                                        Code CWE_ID CWE_Desc  \
# 0                              package androidx.preference;
# 1
# 2                                 import a.a.a.a.class_698;
# 3                           import android.content.Context;
# 4                    import android.content.res.TypedArray;
# ...                                                     ...    ...      ...
# ...

# %%
del vulnerability_df['Unnamed: 0']

# %%
del vulnerability_df['app_name']

# %%
vulnerability_df=vulnerability_df.rename(columns = {'qark_name':'Description'})

# %%
vulnerability_df=vulnerability_df.rename(columns = {'severity':'Severity'})

# %%
vulnerability_df
# Out:
#          category Severity Description  \
# 0
# 1
# 2
# 3
# 4
# ...           ...      ...         ...
# 15288184
# 15288185
# 15288186
# 15288187
# 15288188
#
#                                                        Code CWE_ID CWE_Desc  \
# 0                              package androidx.preference;
# 1
# 2                                 import a.a.a.a.class_698;
# 3                           import android.content.Context;
# 4                    import android.content.res.TypedArray;
# ...                                                     ...    ...      ...
# 15288184  public static ArrayList<WeatherStation> fromJs...
# 15288185  ArrayList<WeatherStation> weatherStations = ne...
# 15288186   for (int i = 0; i < jsonObjects.length(); i++) {
# 15288187  weatherStations.add(new WeatherStation(jsonObj...
# 15288188                            return weatherStations;
#
#           Vulnerability_status  \
# 0                            0
# 1                            0
# ...

# %%
vulnerability_df=vulnerability_df.drop_duplicates(subset=['processed_code', 'CWE_ID'], keep='first')

# %%
vulnerability_df.reset_index(inplace=True)
vulnerability_df = vulnerability_df.rename(columns = {'index':'index'})

# %%
vulnerability_df
# Out:
#             index category Severity Description  \
# 0               0
# 1               1
# 2               2
# 3               3
# 4               4
# ...           ...      ...      ...         ...
# 8824982  15288184
# 8824983  15288185
# 8824984  15288186
# 8824985  15288187
# 8824986  15288188
#
#                                                       Code CWE_ID CWE_Desc  \
# 0                             package androidx.preference;
# 1
# 2                                import a.a.a.a.class_698;
# 3                          import android.content.Context;
# 4                   import android.content.res.TypedArray;
# ...                                                    ...    ...      ...
# 8824982  public static ArrayList<WeatherStation> fromJs...
# 8824983  ArrayList<WeatherStation> weatherStations = ne...
# 8824984   for (int i = 0; i < jsonObjects.length(); i++) {
# 8824985  weatherStations.add(new WeatherStation(jsonObj...
# ...

# %%
vulnerability_df.to_csv("LVDAndro_All_Qark_Processed.csv", index=False)
