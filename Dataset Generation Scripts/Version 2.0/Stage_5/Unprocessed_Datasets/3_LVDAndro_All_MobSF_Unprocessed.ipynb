# %%
import pandas as pd

# %%
csv_1_round_No_Source = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_No_Source_Unprocessed_Dataset_1_Round.csv"
csv_2_round_No_Source = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_No_Source_Unprocessed_Dataset_2_Round.csv"

csv_1_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_1_Round.csv"
csv_2_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_2_Round.csv"
csv_3_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_3_Round.csv"
csv_4_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_4_Round.csv"
csv_5_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_5_Round.csv"
csv_6_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_6_Round.csv"
csv_7_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_7_Round.csv"

csv_1_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_1_Round.csv"
csv_2_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_2_Round.csv"
csv_3_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_3_Round.csv"
csv_4_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_4_Round.csv"
csv_5_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_5_Round.csv"
csv_6_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_6_Round.csv"
csv_7_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_7_Round.csv"

# %%
vulnerability_df_1_round = pd.read_csv(csv_1_round)

# %%
vulnerability_df_1_round.columns
# Out:
# Index(['ID', 'Description', 'Type', 'Pattern', 'Code', 'Severity',
#        'Input Case', 'CVSS', 'CWE_ID', 'CWE_Desc', 'OWASP_Mobile',
#        'OWSAP_MASVS', 'Reference', 'Vulnerability_status'],
#       dtype='object')

# %%
vulnerability_df_1_round.loc[vulnerability_df_1_round['Vulnerability_status'] == 1].head().fillna("")
# Out:
#                    ID                                        Description  \
# 184   android_logging  The App logs information. Sensitive informatio...
# 583   android_logging  The App logs information. Sensitive informatio...
# 1254  android_logging  The App logs information. Sensitive informatio...
# 1530  android_logging  The App logs information. Sensitive informatio...
# 1607  android_logging  The App logs information. Sensitive informatio...
#
#        Type                                            Pattern  \
# 184   Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 583   Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 1254  Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 1530  Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 1607  Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
#
#                                                    Code Severity Input Case  \
# ...

# %%
vulnerability_df_1_round_No_Source = pd.read_csv(csv_1_round_No_Source, low_memory=False).fillna("")

vulnerability_df_2_round_No_Source = pd.read_csv(csv_2_round_No_Source, low_memory=False).fillna("")

vulnerability_df_1_round = pd.read_csv(csv_1_round, low_memory=False).fillna("")

vulnerability_df_2_round = pd.read_csv(csv_2_round, low_memory=False).fillna("")

vulnerability_df_3_round = pd.read_csv(csv_3_round, low_memory=False).fillna("")

vulnerability_df_4_round = pd.read_csv(csv_4_round, low_memory=False).fillna("")

vulnerability_df_5_round = pd.read_csv(csv_5_round, low_memory=False).fillna("")

vulnerability_df_6_round = pd.read_csv(csv_6_round, low_memory=False).fillna("")

vulnerability_df_7_round = pd.read_csv(csv_7_round, low_memory=False).fillna("")


vulnerability_df_1_round_Files = pd.read_csv(csv_1_round_Files, low_memory=False).fillna("")

vulnerability_df_2_round_Files = pd.read_csv(csv_2_round_Files, low_memory=False).fillna("")

vulnerability_df_3_round_Files = pd.read_csv(csv_3_round_Files, low_memory=False).fillna("")

vulnerability_df_4_round_Files = pd.read_csv(csv_4_round_Files, low_memory=False).fillna("")

vulnerability_df_5_round_Files = pd.read_csv(csv_5_round_Files, low_memory=False).fillna("")

vulnerability_df_6_round_Files = pd.read_csv(csv_6_round_Files, low_memory=False).fillna("")

vulnerability_df_7_round_Files = pd.read_csv(csv_7_round_Files, low_memory=False).fillna("")





vulnerability_df= pd.concat([vulnerability_df_1_round_No_Source, vulnerability_df_2_round_No_Source,vulnerability_df_1_round, vulnerability_df_2_round, vulnerability_df_3_round, vulnerability_df_4_round, vulnerability_df_5_round, vulnerability_df_6_round, vulnerability_df_7_round,vulnerability_df_1_round_Files, vulnerability_df_2_round_Files, vulnerability_df_3_round_Files, vulnerability_df_4_round_Files, vulnerability_df_5_round_Files, vulnerability_df_6_round_Files, vulnerability_df_7_round_Files], ignore_index=True)

# %%
vulnerability_df
# Out:
#          ID Description Type Pattern  \
# 0
# 1
# 2
# 3
# 4
# ...      ..         ...  ...     ...
# 10867936
# 10867937
# 10867938
# 10867939
# 10867940
#
#                                                        Code Severity  \
# 0                              package de.cketti.changelog;
# 1
# 2                           import android.content.Context;
# 3                 import android.content.SharedPreferences;
# 4                    import android.content.pm.PackageInfo;
# ...                                                     ...      ...
# 10867936  Log.d(TAG, "onStart: No blueooth adapter detec...
# 10867937                            Log.d(TAG, "onResume");
# 10867938  Log.e(TAG, "Destroying activity. Stopping blue...
# 10867939  Log.d(TAG, "handleMessage():  MESSAGE_STATE_CH...
# 10867940  Log.d(TAG, "Unable to connect, bluetooth unava...
#
#          Input Case CVSS CWE_ID CWE_Desc OWASP_Mobile OWSAP_MASVS Reference  \
# 0
# 1
# 2
# 3
# 4
# ...

# %%
vulnerability_df=vulnerability_df.drop_duplicates(subset=['Code', 'CWE_ID'], keep='first')

# %%
del vulnerability_df['ID']

# %%
vulnerability_df.reset_index(inplace=True)
vulnerability_df = vulnerability_df.rename(columns = {'index':'index'})

# %%
vulnerability_df
# Out:
#             index                                        Description   Type  \
# 0               0
# 1               1
# 2               2
# 3               3
# 4               4
# ...           ...                                                ...    ...
# 7898513  10867922
# 7898514  10867926  The App logs information. Sensitive informatio...  Regex
# 7898515  10867927  The App logs information. Sensitive informatio...  Regex
# 7898516  10867933
# 7898517  10867939
#
#                                                    Pattern  \
# 0
# 1
# 2
# 3
# 4
# ...                                                    ...
# 7898513
# 7898514  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 7898515  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 7898516
# 7898517
#
#                                                       Code Severity  \
# 0                             package de.cketti.changelog;
# 1
# 2                          import android.content.Context;
# ...

# %%
vulnerability_df.to_csv("LVDAndro_All_MobSF_Unprocessed.csv", index=False)
