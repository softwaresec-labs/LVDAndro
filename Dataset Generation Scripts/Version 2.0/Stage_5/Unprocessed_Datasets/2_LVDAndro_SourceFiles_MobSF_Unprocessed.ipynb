# %%
import pandas as pd

# %%
csv_1_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_1_Round.csv"
csv_2_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_2_Round.csv"
csv_3_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_3_Round.csv"
csv_4_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_4_Round.csv"
csv_5_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_5_Round.csv"
csv_6_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_6_Round.csv"
csv_7_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_7_Round.csv"

# %%
vulnerability_df_1_round = pd.read_csv(csv_1_round)

# %%
vulnerability_df_1_round.columns
# Out:
# Index(['ID', 'Description', 'Type', 'Pattern', 'Code', 'Severity',
#        'Input Case', 'CVSS', 'CWE_ID', 'CWE_Desc', 'OWASP_Mobile',
#        'OWSAP_MASVS', 'Reference', 'Vulnerability_status'],
#       dtype='object')

# %%
vulnerability_df_1_round.loc[vulnerability_df_1_round['Vulnerability_status'] == 1].head().fillna("")
# Out:
#                         ID                                        Description  \
# 95         android_logging  The App logs information. Sensitive informatio...
# 326        android_logging  The App logs information. Sensitive informatio...
# 330        android_logging  The App logs information. Sensitive informatio...
# 354  android_write_app_dir  App can write to App Directory. Sensitive Info...
# 541        android_logging  The App logs information. Sensitive informatio...
#
#         Type                                            Pattern  \
# 95     Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 326    Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 330    Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 354  RegexOr         ['MODE_PRIVATE', 'Context\\.MODE_PRIVATE']
# 541    Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
#
#                                                   Code Severity Input Case  \
# ...

# %%
vulnerability_df_1_round = pd.read_csv(csv_1_round, low_memory=False).fillna("")

vulnerability_df_2_round = pd.read_csv(csv_2_round, low_memory=False).fillna("")

vulnerability_df_3_round = pd.read_csv(csv_3_round, low_memory=False).fillna("")

vulnerability_df_4_round = pd.read_csv(csv_4_round, low_memory=False).fillna("")

vulnerability_df_5_round = pd.read_csv(csv_5_round, low_memory=False).fillna("")

vulnerability_df_6_round = pd.read_csv(csv_6_round, low_memory=False).fillna("")

vulnerability_df_7_round = pd.read_csv(csv_7_round, low_memory=False).fillna("")



vulnerability_df= pd.concat([vulnerability_df_1_round, vulnerability_df_2_round, vulnerability_df_3_round, vulnerability_df_4_round, vulnerability_df_5_round, vulnerability_df_6_round, vulnerability_df_7_round], ignore_index=True)

# %%
vulnerability_df
# Out:
#         ID Description Type Pattern  \
# 0
# 1
# 2
# 3
# 4
# ...     ..         ...  ...     ...
# 2477723
# 2477724
# 2477725
# 2477726
# 2477727
#
#                                                       Code Severity  \
# 0                       // Copyright 2019 Matthew Chandler
# 1
# 2        // Permission is hereby granted, free of charg...
# 3        // of this software and associated documentati...
# 4        // in the Software without restriction, includ...
# ...                                                    ...      ...
# 2477723  Log.d(TAG, "onStart: No blueooth adapter detec...
# 2477724                            Log.d(TAG, "onResume");
# 2477725  Log.e(TAG, "Destroying activity. Stopping blue...
# 2477726  Log.d(TAG, "handleMessage():  MESSAGE_STATE_CH...
# 2477727  Log.d(TAG, "Unable to connect, bluetooth unava...
#
#         Input Case CVSS CWE_ID CWE_Desc OWASP_Mobile OWSAP_MASVS Reference  \
# 0
# 1
# 2
# 3
# 4
# ...

# %%
vulnerability_df=vulnerability_df.drop_duplicates(subset=['Code', 'CWE_ID'], keep='first')

# %%
del vulnerability_df['ID']

# %%
vulnerability_df.reset_index(inplace=True)
vulnerability_df = vulnerability_df.rename(columns = {'index':'index'})

# %%
vulnerability_df
# Out:
#            index Description Type Pattern  \
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...         ...  ...     ...
# 2174684  2477721
# 2174685  2477723
# 2174686  2477725
# 2174687  2477726
# 2174688  2477727
#
#                                                       Code Severity  \
# 0                       // Copyright 2019 Matthew Chandler
# 1
# 2        // Permission is hereby granted, free of charg...
# 3        // of this software and associated documentati...
# 4        // in the Software without restriction, includ...
# ...                                                    ...      ...
# 2174684  Log.d(TAG, "onStart: Blueooth adapter detected...
# 2174685  Log.d(TAG, "onStart: No blueooth adapter detec...
# 2174686  Log.e(TAG, "Destroying activity. Stopping blue...
# 2174687  Log.d(TAG, "handleMessage():  MESSAGE_STATE_CH...
# 2174688  Log.d(TAG, "Unable to connect, bluetooth unava...
#
# ...

# %%
vulnerability_df.to_csv("LVDAndro_SourceFiles_MobSF_Unprocessed.csv", index=False)
