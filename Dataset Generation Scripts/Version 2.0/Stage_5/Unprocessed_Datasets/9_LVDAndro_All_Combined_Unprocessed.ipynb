# %%
import pandas as pd

# %%
MobSF_csv_1_round_No_Source = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_No_Source_Unprocessed_Dataset_1_Round.csv"
MobSF_csv_2_round_No_Source = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_No_Source_Unprocessed_Dataset_2_Round.csv"

MobSF_csv_1_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_1_Round.csv"
MobSF_csv_2_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_2_Round.csv"
MobSF_csv_3_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_3_Round.csv"
MobSF_csv_4_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_4_Round.csv"
MobSF_csv_5_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_5_Round.csv"
MobSF_csv_6_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_6_Round.csv"
MobSF_csv_7_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_7_Round.csv"

MobSF_csv_1_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_1_Round.csv"
MobSF_csv_2_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_2_Round.csv"
MobSF_csv_3_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_3_Round.csv"
MobSF_csv_4_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_4_Round.csv"
MobSF_csv_5_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_5_Round.csv"
MobSF_csv_6_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_6_Round.csv"
MobSF_csv_7_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/MobSF_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_7_Round.csv"

Qark_csv_1_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_1_Round.csv"
Qark_csv_2_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_2_Round.csv"
Qark_csv_3_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_3_Round.csv"
Qark_csv_4_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_4_Round.csv"
Qark_csv_5_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_5_Round.csv"
Qark_csv_6_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_6_Round.csv"
Qark_csv_7_round = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_App_Unprocessed_Dataset_7_Round.csv"

Qark_csv_1_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_1_Round.csv"
Qark_csv_2_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_2_Round.csv"
Qark_csv_3_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_3_Round.csv"
Qark_csv_4_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_4_Round.csv"
Qark_csv_5_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_5_Round.csv"
Qark_csv_6_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_6_Round.csv"
Qark_csv_7_round_Files = "I:/PhD/Model_Building/Stage_4_Building_Vulnerability_Dataset/Qark_Unprocessed_Datasets/Scanned_Files_Unprocessed_Dataset_7_Round.csv"

# %%
MobSF_vulnerability_df_1_round_No_Source = pd.read_csv(MobSF_csv_1_round_No_Source, low_memory=False).fillna("")
MobSF_vulnerability_df_2_round_No_Source = pd.read_csv(MobSF_csv_2_round_No_Source, low_memory=False).fillna("")

MobSF_vulnerability_df_1_round = pd.read_csv(MobSF_csv_1_round, low_memory=False).fillna("")
MobSF_vulnerability_df_2_round = pd.read_csv(MobSF_csv_2_round, low_memory=False).fillna("")
MobSF_vulnerability_df_3_round = pd.read_csv(MobSF_csv_3_round, low_memory=False).fillna("")
MobSF_vulnerability_df_4_round = pd.read_csv(MobSF_csv_4_round, low_memory=False).fillna("")
MobSF_vulnerability_df_5_round = pd.read_csv(MobSF_csv_5_round, low_memory=False).fillna("")
MobSF_vulnerability_df_6_round = pd.read_csv(MobSF_csv_6_round, low_memory=False).fillna("")
MobSF_vulnerability_df_7_round = pd.read_csv(MobSF_csv_7_round, low_memory=False).fillna("")

MobSF_vulnerability_df_1_round_Files = pd.read_csv(MobSF_csv_1_round_Files, low_memory=False).fillna("")
MobSF_vulnerability_df_2_round_Files = pd.read_csv(MobSF_csv_2_round_Files, low_memory=False).fillna("")
MobSF_vulnerability_df_3_round_Files = pd.read_csv(MobSF_csv_3_round_Files, low_memory=False).fillna("")
MobSF_vulnerability_df_4_round_Files = pd.read_csv(MobSF_csv_4_round_Files, low_memory=False).fillna("")
MobSF_vulnerability_df_5_round_Files = pd.read_csv(MobSF_csv_5_round_Files, low_memory=False).fillna("")
MobSF_vulnerability_df_6_round_Files = pd.read_csv(MobSF_csv_6_round_Files, low_memory=False).fillna("")
MobSF_vulnerability_df_7_round_Files = pd.read_csv(MobSF_csv_7_round_Files, low_memory=False).fillna("")

vulnerability_df_MobSF= pd.concat([MobSF_vulnerability_df_1_round_No_Source, MobSF_vulnerability_df_2_round_No_Source,MobSF_vulnerability_df_1_round, MobSF_vulnerability_df_2_round, MobSF_vulnerability_df_3_round, MobSF_vulnerability_df_4_round, MobSF_vulnerability_df_5_round, MobSF_vulnerability_df_6_round, MobSF_vulnerability_df_7_round,MobSF_vulnerability_df_1_round_Files, MobSF_vulnerability_df_2_round_Files, MobSF_vulnerability_df_3_round_Files, MobSF_vulnerability_df_4_round_Files, MobSF_vulnerability_df_5_round_Files, MobSF_vulnerability_df_6_round_Files, MobSF_vulnerability_df_7_round_Files], ignore_index=True)
vulnerability_df_MobSF=vulnerability_df_MobSF.drop_duplicates(subset=['Code', 'CWE_ID'], keep='first')

Qark_vulnerability_df_1_round = pd.read_csv(Qark_csv_1_round, low_memory=False).fillna("")
Qark_vulnerability_df_2_round = pd.read_csv(Qark_csv_2_round, low_memory=False).fillna("")
Qark_vulnerability_df_3_round = pd.read_csv(Qark_csv_3_round, low_memory=False).fillna("")
Qark_vulnerability_df_4_round = pd.read_csv(Qark_csv_4_round, low_memory=False).fillna("")
Qark_vulnerability_df_5_round = pd.read_csv(Qark_csv_5_round, low_memory=False).fillna("")
Qark_vulnerability_df_6_round = pd.read_csv(Qark_csv_6_round, low_memory=False).fillna("")
Qark_vulnerability_df_7_round = pd.read_csv(Qark_csv_7_round, low_memory=False).fillna("")


Qark_vulnerability_df_1_round_Files = pd.read_csv(Qark_csv_1_round_Files, low_memory=False).fillna("")
Qark_vulnerability_df_2_round_Files = pd.read_csv(Qark_csv_2_round_Files, low_memory=False).fillna("")
Qark_vulnerability_df_3_round_Files = pd.read_csv(Qark_csv_3_round_Files, low_memory=False).fillna("")
Qark_vulnerability_df_4_round_Files = pd.read_csv(Qark_csv_4_round_Files, low_memory=False).fillna("")
Qark_vulnerability_df_5_round_Files = pd.read_csv(Qark_csv_5_round_Files, low_memory=False).fillna("")
Qark_vulnerability_df_6_round_Files = pd.read_csv(Qark_csv_6_round_Files, low_memory=False).fillna("")
Qark_vulnerability_df_7_round_Files = pd.read_csv(Qark_csv_7_round_Files, low_memory=False).fillna("")

vulnerability_df_Qark= pd.concat([Qark_vulnerability_df_1_round, Qark_vulnerability_df_2_round, Qark_vulnerability_df_3_round, Qark_vulnerability_df_4_round, Qark_vulnerability_df_5_round, Qark_vulnerability_df_6_round, Qark_vulnerability_df_7_round,Qark_vulnerability_df_1_round_Files, Qark_vulnerability_df_2_round_Files, Qark_vulnerability_df_3_round_Files, Qark_vulnerability_df_4_round_Files, Qark_vulnerability_df_5_round_Files, Qark_vulnerability_df_6_round_Files, Qark_vulnerability_df_7_round_Files], ignore_index=True)
vulnerability_df_Qark=vulnerability_df_Qark.drop_duplicates(subset=['Code', 'CWE_ID'], keep='first')

# %%
vulnerability_df_MobSF
# Out:
#                        ID                                        Description  \
# 0
# 1
# 2
# 3
# 4
# ...                   ...                                                ...
# 10867922
# 10867926  android_logging  The App logs information. Sensitive informatio...
# 10867927  android_logging  The App logs information. Sensitive informatio...
# 10867933
# 10867939
#
#            Type                                            Pattern  \
# 0
# 1
# 2
# 3
# 4
# ...         ...                                                ...
# 10867922
# 10867926  Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 10867927  Regex  Log\.(v|d|i|w|e|f|s)|System\.out\.print|System...
# 10867933
# 10867939
#
#                                                        Code Severity  \
# 0                              package de.cketti.changelog;
# 1
# 2                           import android.content.Context;
# 3                 import android.content.SharedPreferences;
# ...

# %%
vulnerability_df_MobSF.columns
# Out:
# Index(['ID', 'Description', 'Type', 'Pattern', 'Code', 'Severity',
#        'Input Case', 'CVSS', 'CWE_ID', 'CWE_Desc', 'OWASP_Mobile',
#        'OWSAP_MASVS', 'Reference', 'Vulnerability_status'],
#       dtype='object')

# %%
del vulnerability_df_MobSF['ID']

# %%
vulnerability_df_Qark
# Out:
#           Unnamed: 0        app_name category severity qark_name  \
# 0                  0         %24hell
# 1                  1         %24hell
# 2                  2         %24hell
# 3                  3         %24hell
# 4                  4         %24hell
# ...              ...             ...      ...      ...       ...
# 17713195      126161  weather-widget
# 17713196      126162  weather-widget
# 17713197      126163  weather-widget
# 17713198      126164  weather-widget
# 17713199      126165  weather-widget
#
#                                                        Code CWE_ID CWE_Desc  \
# 0                              package androidx.preference;
# 1
# 2                                 import a.a.a.a.class_698;
# 3                           import android.content.Context;
# 4                    import android.content.res.TypedArray;
# ...                                                     ...    ...      ...
# ...

# %%
vulnerability_df_Qark.columns
# Out:
# Index(['Unnamed: 0', 'app_name', 'category', 'severity', 'qark_name', 'Code',
#        'CWE_ID', 'CWE_Desc', 'Vulnerability_status'],
#       dtype='object')

# %%
del vulnerability_df_Qark['Unnamed: 0']
del vulnerability_df_Qark['app_name']

# %%
vulnerability_df=pd.concat([vulnerability_df_MobSF, vulnerability_df_Qark], ignore_index=True).fillna("")

# %%
vulnerability_df
# Out:
#          Description Type Pattern  \
# 0
# 1
# 2
# 3
# 4
# ...              ...  ...     ...
# 18178142
# 18178143
# 18178144
# 18178145
# 18178146
#
#                                                        Code Severity  \
# 0                              package de.cketti.changelog;
# 1
# 2                           import android.content.Context;
# 3                 import android.content.SharedPreferences;
# 4                    import android.content.pm.PackageInfo;
# ...                                                     ...      ...
# 18178142  public static ArrayList<WeatherStation> fromJs...
# 18178143  ArrayList<WeatherStation> weatherStations = ne...
# 18178144   for (int i = 0; i < jsonObjects.length(); i++) {
# 18178145  weatherStations.add(new WeatherStation(jsonObj...
# 18178146                            return weatherStations;
#
#          Input Case CVSS CWE_ID CWE_Desc OWASP_Mobile OWSAP_MASVS Reference  \
# 0
# 1
# 2
# 3
# 4
# ...

# %%
vulnerability_df=vulnerability_df.drop_duplicates(subset=['Code', 'CWE_ID'], keep='first')

# %%
vulnerability_df.reset_index(inplace=True)
vulnerability_df = vulnerability_df.rename(columns = {'index':'index'})

# %%
vulnerability_df
# Out:
#              index Description Type Pattern  \
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
# ...            ...         ...  ...     ...
# 16633358  18178120
# 16633359  18178121
# 16633360  18178122
# 16633361  18178123
# 16633362  18178124
#
#                                                        Code Severity  \
# 0                              package de.cketti.changelog;
# 1
# 2                           import android.content.Context;
# 3                 import android.content.SharedPreferences;
# 4                    import android.content.pm.PackageInfo;
# ...                                                     ...      ...
# 16633358              issueButton.setOnClickListener(v -> {
# 16633359  intent.setData(Uri.parse("https://github.com/d...
# 16633360  Button contactButton = findViewById(R.id.conta...
# 16633361            contactButton.setOnClickListener(v -> {
# ...

# %%
vulnerability_df.to_csv("LVDAndro_All_Combined_Unprocessed.csv", index=False)
