# %%
# !pip install requests-toolbelt
# Out:
# Requirement already satisfied: requests-toolbelt in c:\users\janak\anaconda3\lib\site-packages (0.9.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.1 in c:\users\janak\anaconda3\lib\site-packages (from requests-toolbelt) (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\janak\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.1->requests-toolbelt) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\janak\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.1->requests-toolbelt) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\janak\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.1->requests-toolbelt) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\janak\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.1->requests-toolbelt) (1.26.4)

# %%
import json
import requests
from requests_toolbelt.multipart.encoder import MultipartEncoder
import subprocess
import os
import json
import requests
import zipfile
import csv
import pandas as pd
import time

# %%
SERVER = "http://localhost:8000"
#DOWNLOAD_BASE_PATH = "D:/PhD/Model_Building/APKs_and_GitRepos"
#DOWNLOAD_BASE_PATH = "D:/PhD/Model_Building/APKs_and_GitRepos/4_Round"
DOWNLOAD_BASE_PATH = "I:///PhD//Model_Building//APKs_and_GitRepos//4_Round"
MOBSF_BASE_PATH = "D:/PhD/Model_Building/Scanners_and_Decompilers/Scanners/MobSF"
APPLICATION_BASE_PATH = "D:/PhD/Model_Building/Stage_2_Analysing_APKs"
APIKEY = "4a9fc3e94941f832d40975a251056079c9be5406891a934ded21a3c0ecdc5119"

# %%
def start_MobSF_server():
    os.chdir(MOBSF_BASE_PATH)
    subprocess.call('start run.bat', shell = True)
    time.sleep(15)

# %%
def upload_apk(apk_file):
    print("***************Uploading file***************")
    multipart_data = MultipartEncoder(fields={'file': (apk_file, open(apk_file, 'rb'), 'application/octet-stream')})
    headers = {'Content-Type': multipart_data.content_type, 'Authorization': APIKEY}
    response = requests.post(SERVER + '/api/v1/upload', data=multipart_data, headers=headers)
    print("***************File uploaded***************")
    return response.text

# %%
def scan_apk(upload_response):
    print("***************Scanning file***************")
    post_dict = json.loads(upload_response)
    headers = {'Authorization': APIKEY}
    response = requests.post(SERVER + '/api/v1/scan', data=post_dict, headers=headers)
    print("***************File scanned***************")
    return response.text

# %%
#This is for delete a scanned file
def delete_scanned_results(scanHash):   
    print("Deleting Scan")
    headers = {'Authorization': APIKEY}
    data = {"hash": scanHash}
    response = requests.post(SERVER + '/api/v1/delete_scan', data=data, headers=headers)
    print(response.text)

# %%
def download_reverse_eningeered_files(app_hash, app_name):
    print("***************Downloading re-eningeered files***************")
  
    #downloading file from the MOBSF server
    url = SERVER+'/generate_downloads/?hash='+app_hash+'&file_type=java'
    
    os.chdir(DOWNLOAD_BASE_PATH+"/"+app_name)    
    if (os.path.isdir("MobSF_Reversed")!=True): 
            os.mkdir("MobSF_Reversed")
    os.chdir("MobSF_Reversed")    
    
    java_files_request = requests.get(url, allow_redirects=True)
    open(app_name+".zip", 'wb').write(java_files_request.content)
    
    #extracting the downloaded zip file
    file_path = DOWNLOAD_BASE_PATH+"/"+app_name+"/MobSF_Reversed"
    zip_file_name = app_name+".zip"
    with zipfile.ZipFile(file_path+"/"+zip_file_name, 'r') as zip_ref:
        zip_ref.extractall(file_path)
    
    #deleting the zip file as it is not necessary
    os.remove(zip_file_name)
    
    print("***************Re-eningeered files downloaded***************")

# %%
def write_scanned_app_details(app_hash, app_name):
    print("***************Writing data to CSV File***************")
    scanned_App_Details_file = open(APPLICATION_BASE_PATH+'/MobSF_Scanned_App_Details.csv', 'a', newline='')
    scanned_App_Details_file_writer = csv.writer(scanned_App_Details_file)       
    scanned_App_Details_file_writer.writerow([app_name,app_hash])  
    scanned_App_Details_file.close()
    print("***************Completed data writing***************")

# %%
def execute_process():
    print("***************Process started***************")
    start_MobSF_server()
    files = os.listdir(DOWNLOAD_BASE_PATH)    
    
    try:
        #Reading scanned apps details
        scanned_apps = pd.read_csv(APPLICATION_BASE_PATH+'/MobSF_Scanned_App_Details.csv')

        for file in files:  
            try:
                print("***************File Name : "+file+".apk***************")
                if(file in scanned_apps.app_name.values):
                    print ("This app is already scanned!")
                else:
                    upload_response = upload_apk(DOWNLOAD_BASE_PATH+"/"+file+"/"+file+".apk")

                    #Retrieveing required information from upload respone
                    json_response = json.loads(upload_response)
                    app_hash = json_response['hash']
                    app_name = json_response['file_name']
                    app_name = app_name[:len(app_name)-4]
                
                    scan_response = scan_apk(upload_response)
                    download_reverse_eningeered_files(app_hash, app_name)
                    write_scanned_app_details(app_hash, app_name)
                    
            except Exception as e:
                print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
                print(e)
                continue
            
    except Exception as ex:
        #File not avaialble means the 1st scan of MobSF
        print("No any scans yet"+ ex)
        
    
    print("***************Process completed***************")

# %%
execute_process()
# Out:
# ***************Process started***************
# ***************File Name : olauncher.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : open-ear.apk***************
# This app is already scanned!
# ***************File Name : open-explorer-beta.apk***************
# This app is already scanned!
# ***************File Name : open-flashlight.apk***************
# This app is already scanned!
# ***************File Name : open-flood.apk***************
# This app is already scanned!
# ***************File Name : open-fndds-viewer.apk***************
# This app is already scanned!
# ***************File Name : open-in-browser.apk***************
# This app is already scanned!
# ***************File Name : open-in-whatsapp.apk***************
# This app is already scanned!
# ***************File Name : open-link-with.apk***************
# This app is already scanned!
# ***************File Name : open-manager.apk***************
# This app is already scanned!
# ***************File Name : open-map.apk***************
# This app is already scanned!
# ***************File Name : open-note-scanner.apk***************
# This app is already scanned!
# ***************File Name : open-pet-food-facts.apk***************
# This app is already scanned!
# ***************File Name : open-pros-cons.apk***************
# This app is already scanned!
# ***************File Name : open-sudoku.apk***************
# This app is already scanned!
# ***************File Name : open-training.apk***************
# This app is already scanned!
# ***************File Name : open-wifi-cleaner.apk***************
# This app is already scanned!
# ***************File Name : opendnsupdater.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : opendocument-reader.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openeventandroid.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# [Errno 2] No such file or directory: 'I:\\PhD\\Model_Building\\APKs_and_GitRepos\\4_Round\\openeventandroid\\MobSF_Reversed\\kotlin\\reflect\\jvm\\internal\\impl\\serialization\\deserialization\\descriptors\\DeserializedClassDescriptor$EnumEntryClassDescriptors$enumEntryByName$1$$special$$inlined$let$lambda$1.java'
# ***************File Name : openfixmap.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openfood.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openfool.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : opengapps-downloader.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openhab.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openhab-beta.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openhub.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openkeychain.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openlauncher.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openmanga.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openmapkit.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openmaps.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openmensa.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openmentoringmobile.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openmoneybox.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openotago.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openpass.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openpods.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openredmine.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openscale.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openshift.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : opensound.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openstud.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : opensyncedlists.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : opentimer.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : opentopomap-viewer.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : opentracks.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : opentracks-osm-dashboard.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : opentrail.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openvegemap.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openvpn-for-android.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openwebweaver.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openwnn.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openworkout.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : openwort.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : opmt.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : opsu.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : opus-1-music-player.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : orbitallivewallpaper.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : orgfdroidfdroidprivilegedota2000zip.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# File is not a zip file
# ***************File Name : orgro.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : orgzly.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : oring-reminder.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : orion-viewer-pdf-djvu.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : orwall.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : os-monitor.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : oschina.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : oscilloscope.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : osm-dashboard-offline-for-opentracks.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : osmand-contour-lines.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : osmand-parking.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : osmand~.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : osmbugs.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : osmfocus-reborn.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# [Errno 2] No such file or directory: 'I:\\PhD\\Model_Building\\APKs_and_GitRepos\\4_Round\\osmfocus-reborn\\MobSF_Reversed\\kotlin\\reflect\\jvm\\internal\\impl\\serialization\\deserialization\\descriptors\\DeserializedClassDescriptor$EnumEntryClassDescriptors$enumEntryByName$1$$special$$inlined$let$lambda$1.java'
# ***************File Name : osmgpxuploader.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : osmtracker-2.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : osrs-helper.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : otobi-keyboard.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : otp-authenticator.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : oui-lookup-and-database.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : outfield.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : overchan.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : overchan-fork.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : overflow.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : oversec.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : oware.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : owncloud.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : owncloud-news-reader.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : owncloud-notes.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : owncloudsms.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : package-manager.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : packet-sender.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : packlist.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : padland.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : page-plus-balance.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : pageturner.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : pain-diary.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : painlessmesh.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : palmcalc.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : palmcalc-2019+.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : panictrigger.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************File Name : papanikolis-submarine.apk***************
# ***************Uploading file***************
# ***************File uploaded***************
# ***************Scanning file***************
# ***************File scanned***************
# ***************Downloading re-eningeered files***************
# ***************Re-eningeered files downloaded***************
# ***************Writing data to CSV File***************
# ***************Completed data writing***************
# ***************Process completed***************
